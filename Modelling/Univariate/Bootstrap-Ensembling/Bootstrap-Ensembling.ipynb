# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pickle

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
print("Checking for GPU availability...")
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print(f"GPU found: {physical_devices}")
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("Memory growth enabled for GPU")
else:
    print("No GPU found, using CPU")
# Out:
# Checking for GPU availability...
# GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Memory growth enabled for GPU

# %%
def load_data(file_path):
    print(f"Loading data from {file_path}...")
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
    df = df.set_index('date')
    print(f"Data loaded. Shape: {df.shape}")
    return df

# %%
def create_sequences(data, seq_length):
    print(f"Creating sequences with window size {seq_length}...")
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    print(f"Sequences created. X shape: {np.array(X).shape}, y shape: {np.array(y).shape}")
    return np.array(X), np.array(y)

# %%
def create_forecast_sequences(data, seq_length, forecast_horizon):
    print(f"Creating forecast sequences with window {seq_length} and horizon {forecast_horizon}...")
    X, y = [], []
    for i in range(len(data) - seq_length - forecast_horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length:i+seq_length+forecast_horizon])
    print(f"Forecast sequences created. X shape: {np.array(X).shape}, y shape: {np.array(y).shape}")
    return np.array(X), np.array(y)

# %%
def calculate_metrics(y_true, y_pred, y_lower, y_upper):
    # Ensure data consistency
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    y_lower = y_lower.flatten()
    y_upper = y_upper.flatten()

    # Check for NaN values
    assert not np.isnan(y_true).any(), "y_true contains NaNs"
    assert not np.isnan(y_pred).any(), "y_pred contains NaNs"

    # RMSE Calculation
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    # PICP Calculation
    within_interval = np.logical_and(y_true >= y_lower, y_true <= y_upper)
    picp = np.mean(within_interval)

    # MPIW Calculation
    mpiw = np.mean(y_upper - y_lower)

    return rmse, picp, mpiw

# %%
def create_train_model(X_train, y_train, forecast_horizon, model_dir, bootstrap_id):
    print(f"Creating and training model for bootstrap {bootstrap_id}...")
    
    # Ensure the model directory exists
    os.makedirs(model_dir, exist_ok=True)
    
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(forecast_horizon)
    ])

    model.compile(optimizer='adam', loss='mse')

    checkpoint_path = os.path.join(model_dir, f"model_{bootstrap_id}.keras")
    
    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        save_weights_only=False,
        verbose=1
    )
    
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    print(f"Model training completed for bootstrap {bootstrap_id}")
    return model, history

# %%
def generate_bootstrap_forecasts(X_train, y_train, X_val, forecast_horizon, num_bootstraps=10, save_results=True):
    print(f"Generating {num_bootstraps} bootstrapped forecasts...")
    
    # Directory for model checkpoints
    model_dir = "model_checkpoints"
    os.makedirs(model_dir, exist_ok=True)
    
    # Directory for results
    results_dir = "forecast_results"
    os.makedirs(results_dir, exist_ok=True)
    
    forecasts = []
    models = []

    for i in range(num_bootstraps):
        print(f"Bootstrap {i+1}/{num_bootstraps}")
        indices = np.random.choice(len(X_train), len(X_train), replace=True)
        X_bootstrap = X_train[indices]
        y_bootstrap = y_train[indices]

        model, _ = create_train_model(X_bootstrap, y_bootstrap, forecast_horizon, model_dir, i)
        models.append(model)

        print(f"Generating predictions for validation set...")
        forecast = model.predict(X_val, verbose=1)
        forecasts.append(forecast)

    forecasts = np.array(forecasts)
    print(f"Forecasts shape: {forecasts.shape}")

    print("Calculating ensemble statistics...")
    mean_forecast = np.mean(forecasts, axis=0)
    lower_bound = np.quantile(forecasts, 0.05, axis=0)
    upper_bound = np.quantile(forecasts, 0.95, axis=0)

    # Save forecasts and bounds to files
    if save_results:
        print("Saving forecast results to files...")
        results = {
            'mean_forecast': mean_forecast,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound,
            'forecasts': forecasts
        }
        
        results_path = os.path.join(results_dir, 'forecast_results.pkl')
        with open(results_path, 'wb') as f:
            pickle.dump(results, f)
        
        print(f"Results saved to {results_path}")

    print("Bootstrap forecasting completed")
    return mean_forecast, lower_bound, upper_bound, models, forecasts

# %%
def load_forecast_results(results_dir="forecast_results"):
    print("Loading forecast results from file...")
    results_path = os.path.join(results_dir, 'forecast_results.pkl')
    
    if not os.path.exists(results_path):
        raise FileNotFoundError(f"Results file not found at {results_path}")
    
    with open(results_path, 'rb') as f:
        results = pickle.load(f)
    
    print("Forecast results loaded successfully")
    return results['mean_forecast'], results['lower_bound'], results['upper_bound'], results['forecasts']

# %%
def load_trained_models(num_bootstraps, model_dir="model_checkpoints"):
    print(f"Loading {num_bootstraps} trained models from {model_dir}...")
    
    if not os.path.exists(model_dir):
        raise FileNotFoundError(f"Model directory {model_dir} not found")
    
    models = []
    for i in range(num_bootstraps):
        model_path = os.path.join(model_dir, f"model_{i}.keras")
        if os.path.exists(model_path):
            model = load_model(model_path)
            models.append(model)
        else:
            print(f"Warning: Model file {model_path} not found")
    
    print(f"Loaded {len(models)} models")
    return models

# %%
def predict_future(model, last_sequence, future_steps, forecast_horizon, scaler, model_id):
    print(f"Predicting future {future_steps} months with model {model_id}...")
    future_predictions = []
    curr_sequence = last_sequence.copy()

    steps_completed = 0
    while steps_completed < future_steps:
        curr_sequence_reshaped = curr_sequence.reshape(1, curr_sequence.shape[0], curr_sequence.shape[1])

        # Predict next forecast_horizon steps
        next_preds = model.predict(curr_sequence_reshaped, verbose=0)[0]

        # Add as many predictions as needed
        steps_to_add = min(forecast_horizon, future_steps - steps_completed)
        future_predictions.extend(next_preds[:steps_to_add])

        # Update the sequence for the next iteration
        curr_sequence = np.roll(curr_sequence, -steps_to_add, axis=0)
        curr_sequence[-steps_to_add:] = next_preds[:steps_to_add].reshape(-1, 1)

        steps_completed += steps_to_add
        if steps_completed % 10 == 0:
            print(f"Completed {steps_completed}/{future_steps} predictions")

    future_predictions = np.array(future_predictions).reshape(-1, 1)
    future_predictions = scaler.inverse_transform(future_predictions)

    print(f"Future predictions completed for model {model_id}")
    return future_predictions

# %%
def generate_future_dates(last_date, num_months):
    print(f"Generating {num_months} future dates from {last_date}...")
    future_dates = pd.date_range(start=last_date, periods=num_months+1, freq='MS')[1:]
    return future_dates

# %%
def calculate_evaluation_metrics(actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv):
    rmse_values = []
    picp_values = []
    mpiw_values = []

    for i in range(len(actual_values)):
        rmse, picp, mpiw = calculate_metrics(
            actual_values[i],
            mean_forecast_inv[i],
            lower_bound_inv[i],
            upper_bound_inv[i]
        )
        rmse_values.append(rmse)
        picp_values.append(picp)
        mpiw_values.append(mpiw)

    print("\n===== EVALUATION METRICS =====")
    print(f"Average RMSE: {np.mean(rmse_values):.4f}")
    print(f"Average PICP: {np.mean(picp_values):.4f}")
    print(f"Average MPIW: {np.mean(mpiw_values):.4f}")
    print("==============================\n")
    
    return np.mean(rmse_values), np.mean(picp_values), np.mean(mpiw_values)

# %%
def plot_forecast(df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv, 
                 future_dates, future_mean, future_lower, future_upper,
                 cycle_24_start, cycle_25_start, forecast_horizon):
    start_date = pd.to_datetime('1996-01-01')
    plt.figure(figsize=(15, 8))

    # Historical data from 1996
    historical_mask = df.index >= start_date
    plt.plot(df.index[historical_mask], df['ssn'][historical_mask], 'b-', label='Historical Data')

    # Validation predictions with uncertainty
    for i in range(len(mean_forecast_inv)):
        pred_dates = val_dates[i:i+forecast_horizon]
        if len(pred_dates) == len(mean_forecast_inv[i]):
            plt.plot(pred_dates, mean_forecast_inv[i], 'r-', alpha=0.5, label='Validation Predictions' if i == 0 else "")
            plt.fill_between(pred_dates, lower_bound_inv[i], upper_bound_inv[i], color='r', alpha=0.2, label='90% Confidence Interval' if i == 0 else "")

    # Future forecasts
    plt.plot(future_dates, future_mean, 'g-', label='Future Predictions')
    plt.fill_between(future_dates, future_lower.flatten(), future_upper.flatten(), color='g', alpha=0.2, label='Future 90% Confidence Interval')
    plt.axvline(x=cycle_24_start, color='k', linestyle='--', label='Cycle 24 Start')
    plt.axvline(x=cycle_25_start, color='k', linestyle='--', label='Cycle 25 Start')
    plt.title('Sunspot Number Forecast with Uncertainty')
    plt.xlabel('Date')
    plt.ylabel('Sunspot Number')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    print("Starting sunspot forecasting process...")
    
    TRAIN_MODELS = True  # Set to False to load pre-trained models
    
    df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv')
    print("Data summary:")
    print(df.describe())

    print("Scaling data...")
    ssn = df['ssn'].values.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    ssn_scaled = scaler.fit_transform(ssn)
    print("Data scaling completed")
    
    # Save scaler for later use
    with open('scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    print("Defining cycle boundaries...")
    cycle_24_start = pd.to_datetime('2008-12-01')
    cycle_25_start = pd.to_datetime('2019-12-01')
    validation_start = pd.to_datetime('2021-01-01')

    print("Splitting data for training and validation...")
    train_data = ssn_scaled[df.index < cycle_25_start]
    val_data = ssn_scaled[(df.index >= validation_start)]
    val_dates = df.index[(df.index >= validation_start)]
    print(f"Training data points: {len(train_data)}")
    print(f"Validation data points: {len(val_data)}")

    # Define forecast horizon
    forecast_horizon = 6  # 6 months

    print("Creating training sequences...")
    seq_length = 8 * 12  # 8 years in months
    X_train, y_train = create_forecast_sequences(train_data, seq_length, forecast_horizon)
    print(f"Training sequences shape: {X_train.shape}, {y_train.shape}")

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

    print("Creating validation sequences...")
    X_val = []
    y_val = []

    for i in range(len(val_dates) - forecast_horizon + 1):
        # Get the previous 8 years before the validation point
        start_idx = df.index.get_loc(val_dates[i]) - seq_length
        end_idx = df.index.get_loc(val_dates[i])
        forecast_end_idx = df.index.get_loc(val_dates[i]) + forecast_horizon

        if start_idx >= 0:
            X_val.append(ssn_scaled[start_idx:end_idx])
            y_val.append(ssn_scaled[end_idx:forecast_end_idx])

    X_val = np.array(X_val)
    y_val = np.array(y_val)

    # Reshape for LSTM
    X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
    print(f"Validation sequences shape: {X_val.shape}, {y_val.shape}")

    # Train or load models
    num_bootstraps = 100
    if TRAIN_MODELS:
        print("Starting bootstrapped ensemble training and forecasting...")
        mean_forecast, lower_bound, upper_bound, models, forecasts = generate_bootstrap_forecasts(
            X_train, y_train, X_val, forecast_horizon, num_bootstraps=num_bootstraps
        )
    else:
        print("Loading pre-trained models and forecast results...")
        mean_forecast, lower_bound, upper_bound, forecasts = load_forecast_results()
        models = load_trained_models(num_bootstraps)

    print("Transforming forecasts back to original scale...")
    # Reshape for inverse transform
    mean_forecast_reshaped = mean_forecast.reshape(-1, forecast_horizon)
    lower_bound_reshaped = lower_bound.reshape(-1, forecast_horizon)
    upper_bound_reshaped = upper_bound.reshape(-1, forecast_horizon)

    # Store original shapes for validation
    print(f"Mean forecast shape before transform: {mean_forecast_reshaped.shape}")
    print(f"Lower bound shape before transform: {lower_bound_reshaped.shape}")
    print(f"Upper bound shape before transform: {upper_bound_reshaped.shape}")

    # Transform back to original scale
    mean_forecast_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in mean_forecast_reshaped])
    lower_bound_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in lower_bound_reshaped])
    upper_bound_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in upper_bound_reshaped])

    print(f"Mean forecast shape after transform: {mean_forecast_inv.shape}")
    print(f"Lower bound shape after transform: {lower_bound_inv.shape}")
    print(f"Upper bound shape after transform: {upper_bound_inv.shape}")

    print("Computing actual values for validation period...")
    actual_values = []
    for i in range(len(y_val)):
        # Transform each sequence
        inv_y = scaler.inverse_transform(y_val[i].reshape(-1, 1)).flatten()
        actual_values.append(inv_y)

    actual_values = np.array(actual_values)
    print(f"Actual values shape: {actual_values.shape}")

    print("Calculating evaluation metrics...")
    avg_rmse, avg_picp, avg_mpiw = calculate_evaluation_metrics(
        actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv
    )

    print("Preparing for future predictions...")
    last_sequence = ssn_scaled[-seq_length:].reshape(seq_length, 1)
    last_date = df.index[-1]
    future_steps = (2030 - last_date.year) * 12 + (12 - last_date.month)
    print(f"Forecasting {future_steps} months ahead, until 2030")
    future_dates = generate_future_dates(last_date, future_steps)

    print("Generating future forecasts with all models...")
    future_forecasts = []
    for i, model in enumerate(models):
        future_forecast = predict_future(model, last_sequence, future_steps, forecast_horizon, scaler, i)
        future_forecasts.append(future_forecast)

    future_forecasts = np.array(future_forecasts)
    print("Calculating ensemble statistics for future predictions...")
    future_mean = np.mean(future_forecasts, axis=0)
    future_lower = np.quantile(future_forecasts, 0.05, axis=0)
    future_upper = np.quantile(future_forecasts, 0.95, axis=0)

    # Save future predictions
    future_results = {
        'future_mean': future_mean,
        'future_lower': future_lower,
        'future_upper': future_upper,
        'future_dates': future_dates
    }
    with open('future_predictions.pkl', 'wb') as f:
        pickle.dump(future_results, f)
    print("Future predictions saved to future_predictions.pkl")

    print("Creating visualization...")
    plot_forecast(
        df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv,
        future_dates, future_mean, future_lower, future_upper,
        cycle_24_start, cycle_25_start, forecast_horizon
    )
    print("Forecasting process completed")
# Out:
# Starting sunspot forecasting process...
# Loading data from /Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv...
# Data loaded. Shape: (3301, 3)
# Data summary:
#                ssn         year        month
# count  3301.000000  3301.000000  3301.000000
# mean     81.844138  1886.541654     6.500151
# std      63.049151    79.422777     3.452063
# min       0.000000  1749.000000     1.000000
# 25%      25.700000  1818.000000     4.000000
# 50%      72.000000  1887.000000     7.000000
# 75%     119.600000  1955.000000     9.000000
# max     285.000000  2024.000000    12.000000
# Scaling data...
# Data scaling completed
# Defining cycle boundaries...
# Splitting data for training and validation...
# Training data points: 3245
# Validation data points: 43
# Creating training sequences...
# Creating forecast sequences with window 96 and horizon 6...
# Forecast sequences created. X shape: (3144, 96, 1), y shape: (3144, 6, 1)
# Training sequences shape: (3144, 96, 1), (3144, 6, 1)
# Creating validation sequences...
# Validation sequences shape: (38, 96, 1), (38, 6, 1)
# Starting bootstrapped ensemble training and forecasting...
# Generating 100 bootstrapped forecasts...
# Bootstrap 1/100
# Creating and training model for bootstrap 0...
# 2025-03-14 00:34:55.052656: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-03-14 00:34:55.052691: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-03-14 00:34:55.052696: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-03-14 00:34:55.052713: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-14 00:34:55.052727: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/envs/ssn/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2025-03-14 00:34:56.102792: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0484
# Epoch 1: val_loss improved from inf to 0.00506, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0481 - val_loss: 0.0051
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0095
# Epoch 2: val_loss improved from 0.00506 to 0.00393, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0095 - val_loss: 0.0039
# Epoch 3/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075
# Epoch 3: val_loss improved from 0.00393 to 0.00312, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0075 - val_loss: 0.0031
# Epoch 4/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0062
# Epoch 4: val_loss did not improve from 0.00312
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0062 - val_loss: 0.0032
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0057
# Epoch 5: val_loss improved from 0.00312 to 0.00272, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0057 - val_loss: 0.0027
# Epoch 6/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0046
# Epoch 6: val_loss improved from 0.00272 to 0.00193, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 7/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0040
# Epoch 7: val_loss improved from 0.00193 to 0.00180, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036
# Epoch 8: val_loss did not improve from 0.00180
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0036 - val_loss: 0.0023
# Epoch 9/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 9: val_loss improved from 0.00180 to 0.00162, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 10/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 10: val_loss improved from 0.00162 to 0.00136, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 11/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 11: val_loss improved from 0.00136 to 0.00134, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027
# Epoch 12: val_loss did not improve from 0.00134
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 13/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 13: val_loss improved from 0.00134 to 0.00125, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 14/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 14: val_loss improved from 0.00125 to 0.00123, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 15: val_loss did not improve from 0.00123
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - val_loss: 0.0014
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025
# Epoch 16: val_loss did not improve from 0.00123
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 17: val_loss improved from 0.00123 to 0.00122, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 18: val_loss did not improve from 0.00122
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 19/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023
# Epoch 19: val_loss did not improve from 0.00122
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 20/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019
# Epoch 20: val_loss improved from 0.00122 to 0.00114, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 21/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 21: val_loss improved from 0.00114 to 0.00112, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 22/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 22: val_loss improved from 0.00112 to 0.00111, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 23/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 23: val_loss improved from 0.00111 to 0.00104, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 24/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 24: val_loss did not improve from 0.00104
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 25/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 25: val_loss did not improve from 0.00104
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 26/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 26: val_loss did not improve from 0.00104
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 27/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 27: val_loss improved from 0.00104 to 0.00101, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 28/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018
# Epoch 28: val_loss improved from 0.00101 to 0.00100, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 29/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 29: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 30/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016
# Epoch 30: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016
# Epoch 31: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 32/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017
# Epoch 32: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017
# Epoch 33: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 34/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 34: val_loss improved from 0.00100 to 0.00100, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 35/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017
# Epoch 35: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 36/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 36: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 37/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016
# Epoch 37: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 38/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 38: val_loss did not improve from 0.00100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 39/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 39: val_loss improved from 0.00100 to 0.00099, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 9.9238e-04
# Epoch 40/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 40: val_loss improved from 0.00099 to 0.00090, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 9.0231e-04
# Epoch 41/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 41: val_loss did not improve from 0.00090
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 42/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 42: val_loss improved from 0.00090 to 0.00085, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 8.4505e-04
# Epoch 43/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 43: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 44/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 44: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 8.5452e-04
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017
# Epoch 45: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 9.4478e-04
# Epoch 46/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 46: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 8.5647e-04
# Epoch 47/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 47: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 48/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 48: val_loss did not improve from 0.00085
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - val_loss: 9.5164e-04
# Epoch 49/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 49: val_loss improved from 0.00085 to 0.00079, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0015 - val_loss: 7.8856e-04
# Epoch 50/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 50: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0014 - val_loss: 8.3445e-04
# Epoch 51/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 51: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0015 - val_loss: 9.4993e-04
# Epoch 52/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 52: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 9.8353e-04
# Epoch 53/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 53: val_loss improved from 0.00079 to 0.00077, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0014 - val_loss: 7.6835e-04
# Epoch 54/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 54: val_loss did not improve from 0.00077
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 7.8511e-04
# Epoch 55/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 55: val_loss did not improve from 0.00077
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 8.2605e-04
# Epoch 56/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 56: val_loss did not improve from 0.00077
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 8.5489e-04
# Epoch 57/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 57: val_loss did not improve from 0.00077
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.7920e-04
# Epoch 58/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 58: val_loss did not improve from 0.00077
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 59/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 59: val_loss improved from 0.00077 to 0.00073, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 7.2631e-04
# Epoch 60/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013
# Epoch 60: val_loss did not improve from 0.00073
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 7.7681e-04
# Epoch 61/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 61: val_loss did not improve from 0.00073
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 8.7292e-04
# Epoch 62/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 62: val_loss did not improve from 0.00073
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 9.2050e-04
# Epoch 63/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 63: val_loss improved from 0.00073 to 0.00069, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 6.9438e-04
# Epoch 64/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 64: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 7.6475e-04
# Epoch 65/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 65: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.5490e-04
# Epoch 66/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 66: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 67/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 67: val_loss improved from 0.00069 to 0.00069, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 6.9176e-04
# Epoch 68/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 68: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 9.3739e-04
# Epoch 69/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012
# Epoch 69: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 7.0654e-04
# Epoch 70/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 70: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 7.3019e-04
# Epoch 71/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 71: val_loss did not improve from 0.00069
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 72/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 72: val_loss improved from 0.00069 to 0.00064, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.4119e-04
# Epoch 73/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 73: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.9040e-04
# Epoch 74/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 74: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 8.8960e-04
# Epoch 75/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 75: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 6.9723e-04
# Epoch 76/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 76: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 6.5293e-04
# Epoch 77/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 77: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.9375e-04
# Epoch 78/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 78: val_loss improved from 0.00064 to 0.00063, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 6.2561e-04
# Epoch 79/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 79: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 8.8361e-04
# Epoch 80/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 80: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 6.4744e-04
# Epoch 81/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 81: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.7952e-04
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 82: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.8207e-04
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 83: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.6528e-04
# Epoch 84/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 84: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.2206e-04
# Epoch 85/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 85: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 7.0036e-04
# Epoch 86/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 86: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.6003e-04
# Epoch 87/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 87: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 9.5181e-04
# Epoch 88/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 88: val_loss improved from 0.00063 to 0.00059, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0012 - val_loss: 5.9498e-04
# Epoch 89/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 89: val_loss did not improve from 0.00059
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.3633e-04
# Epoch 90/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013
# Epoch 90: val_loss did not improve from 0.00059
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 91/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 91: val_loss did not improve from 0.00059
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 6.2617e-04
# Epoch 92/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 92: val_loss did not improve from 0.00059
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 6.5793e-04
# Epoch 93/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011
# Epoch 93: val_loss improved from 0.00059 to 0.00057, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0011 - val_loss: 5.7006e-04
# Epoch 94/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 94: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.8925e-04
# Epoch 95/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 95: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.9501e-04
# Epoch 96/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012
# Epoch 96: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 5.7258e-04
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 97: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.1594e-04
# Epoch 98/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 98: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.1150e-04
# Epoch 99/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0010
# Epoch 99: val_loss did not improve from 0.00057
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010 - val_loss: 6.2547e-04
# Epoch 100/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011
# Epoch 100: val_loss improved from 0.00057 to 0.00055, saving model to model_checkpoints/model_0.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 5.5300e-04
# Restoring model weights from the end of the best epoch: 100.
# Model training completed for bootstrap 0
# Generating predictions for validation set...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Bootstrap 2/100
# Creating and training model for bootstrap 1...
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0620
# Epoch 1: val_loss improved from inf to 0.00578, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0617 - val_loss: 0.0058
# Epoch 2/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0112
# Epoch 2: val_loss improved from 0.00578 to 0.00342, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - val_loss: 0.0034
# Epoch 3/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0077
# Epoch 3: val_loss improved from 0.00342 to 0.00283, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0077 - val_loss: 0.0028
# Epoch 4/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066
# Epoch 4: val_loss improved from 0.00283 to 0.00258, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 5/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0057
# Epoch 5: val_loss improved from 0.00258 to 0.00213, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 6/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052
# Epoch 6: val_loss did not improve from 0.00213
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0050
# Epoch 7: val_loss improved from 0.00213 to 0.00183, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 8/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040
# Epoch 8: val_loss improved from 0.00183 to 0.00165, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0040 - val_loss: 0.0017
# Epoch 9/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039
# Epoch 9: val_loss improved from 0.00165 to 0.00163, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 10: val_loss improved from 0.00163 to 0.00159, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 11/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034
# Epoch 11: val_loss improved from 0.00159 to 0.00121, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 12/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 12: val_loss did not improve from 0.00121
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 13/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029
# Epoch 13: val_loss did not improve from 0.00121
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 14/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028
# Epoch 14: val_loss did not improve from 0.00121
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 15/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 15: val_loss improved from 0.00121 to 0.00118, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 16/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026
# Epoch 16: val_loss improved from 0.00118 to 0.00113, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 17/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022
# Epoch 17: val_loss improved from 0.00113 to 0.00111, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 18/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 18: val_loss did not improve from 0.00111
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 19/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 19: val_loss did not improve from 0.00111
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022
# Epoch 20: val_loss improved from 0.00111 to 0.00106, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022
# Epoch 21: val_loss did not improve from 0.00106
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 22: val_loss improved from 0.00106 to 0.00103, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 23: val_loss did not improve from 0.00103
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 24/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020
# Epoch 24: val_loss improved from 0.00103 to 0.00103, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 25/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 25: val_loss improved from 0.00103 to 0.00101, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 26: val_loss did not improve from 0.00101
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 27: val_loss did not improve from 0.00101
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 28/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 28: val_loss improved from 0.00101 to 0.00097, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0021 - val_loss: 9.7338e-04
# Epoch 29/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 29: val_loss did not improve from 0.00097
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 30: val_loss did not improve from 0.00097
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 9.9419e-04
# Epoch 31/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 31: val_loss improved from 0.00097 to 0.00097, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 9.6881e-04
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 32: val_loss did not improve from 0.00097
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 33/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 33: val_loss improved from 0.00097 to 0.00091, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0019 - val_loss: 9.0812e-04
# Epoch 34/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00091
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 9.9653e-04
# Epoch 35/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 35: val_loss did not improve from 0.00091
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 9.7754e-04
# Epoch 36/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019
# Epoch 36: val_loss did not improve from 0.00091
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 9.2316e-04
# Epoch 37/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017
# Epoch 37: val_loss did not improve from 0.00091
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 9.5199e-04
# Epoch 38/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 38: val_loss improved from 0.00091 to 0.00088, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0016 - val_loss: 8.7612e-04
# Epoch 39/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017
# Epoch 39: val_loss improved from 0.00088 to 0.00087, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0017 - val_loss: 8.7353e-04
# Epoch 40/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017
# Epoch 40: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 41/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016
# Epoch 41: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 42/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017
# Epoch 42: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0017 - val_loss: 8.9058e-04
# Epoch 43/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016
# Epoch 43: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0016 - val_loss: 9.5784e-04
# Epoch 44/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017
# Epoch 44: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017 - val_loss: 9.1339e-04
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016
# Epoch 45: val_loss did not improve from 0.00087
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0016 - val_loss: 9.1865e-04
# Epoch 46/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 46: val_loss improved from 0.00087 to 0.00082, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - val_loss: 8.2171e-04
# Epoch 47/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 47: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - val_loss: 8.4489e-04
# Epoch 48/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015
# Epoch 48: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 8.6189e-04
# Epoch 49/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016
# Epoch 49: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 8.8235e-04
# Epoch 50/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016
# Epoch 50: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 8.6600e-04
# Epoch 51/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 51: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 8.7382e-04
# Epoch 52/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 52: val_loss did not improve from 0.00082
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 9.2416e-04
# Epoch 53/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 53: val_loss improved from 0.00082 to 0.00079, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 7.8937e-04
# Epoch 54/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 54: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 8.3435e-04
# Epoch 55/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016
# Epoch 55: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - val_loss: 8.6726e-04
# Epoch 56/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 56: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 8.3244e-04
# Epoch 57/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015
# Epoch 57: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 58/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 58: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - val_loss: 8.0765e-04
# Epoch 59/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 59: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 8.4500e-04
# Epoch 60/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 60: val_loss improved from 0.00079 to 0.00075, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 7.5151e-04
# Epoch 61/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 61: val_loss did not improve from 0.00075
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 8.0133e-04
# Epoch 62/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0015
# Epoch 62: val_loss did not improve from 0.00075
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 8.7717e-04
# Epoch 63/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 63: val_loss did not improve from 0.00075
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 7.9123e-04
# Epoch 64/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015
# Epoch 64: val_loss improved from 0.00075 to 0.00074, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 7.3987e-04
# Epoch 65/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 65: val_loss did not improve from 0.00074
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 8.5371e-04
# Epoch 66/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 66: val_loss did not improve from 0.00074
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0014 - val_loss: 7.5444e-04
# Epoch 67/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 67: val_loss did not improve from 0.00074
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 7.8250e-04
# Epoch 68/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 68: val_loss did not improve from 0.00074
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0014 - val_loss: 7.8108e-04
# Epoch 69/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 69: val_loss did not improve from 0.00074
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 7.6836e-04
# Epoch 70/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 70: val_loss improved from 0.00074 to 0.00073, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0013 - val_loss: 7.2989e-04
# Epoch 71/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 71: val_loss improved from 0.00073 to 0.00071, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 7.1091e-04
# Epoch 72/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0014
# Epoch 72: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0014 - val_loss: 7.6416e-04
# Epoch 73/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0014
# Epoch 73: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - val_loss: 7.6866e-04
# Epoch 74/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 74: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 7.1110e-04
# Epoch 75/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 75: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 8.6432e-04
# Epoch 76/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 76: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 7.5578e-04
# Epoch 77/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 77: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.1815e-04
# Epoch 78/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 78: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.4939e-04
# Epoch 79/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013
# Epoch 79: val_loss did not improve from 0.00071
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 7.6494e-04
# Epoch 80/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014
# Epoch 80: val_loss improved from 0.00071 to 0.00066, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 6.5642e-04
# Epoch 81/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 81: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.1420e-04
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 82: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 6.8123e-04
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 83: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 8.1438e-04
# Epoch 84/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 84: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.8187e-04
# Epoch 85/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 85: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.0319e-04
# Epoch 86/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 86: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 7.7239e-04
# Epoch 87/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 87: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.4158e-04
# Epoch 88/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 88: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 7.6568e-04
# Epoch 89/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 89: val_loss did not improve from 0.00066
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 7.4856e-04
# Epoch 90/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 90: val_loss improved from 0.00066 to 0.00064, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.3687e-04
# Epoch 91/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 91: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.5814e-04
# Epoch 92/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013
# Epoch 92: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.3993e-04
# Epoch 93/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 93: val_loss improved from 0.00064 to 0.00063, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0013 - val_loss: 6.3033e-04
# Epoch 94/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0011
# Epoch 94: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 7.1120e-04
# Epoch 95/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 95: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 6.3404e-04
# Epoch 96/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 96: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - val_loss: 8.0707e-04
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012
# Epoch 97: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 6.9015e-04
# Epoch 98/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 98: val_loss did not improve from 0.00063
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 6.3344e-04
# Epoch 99/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 99: val_loss improved from 0.00063 to 0.00061, saving model to model_checkpoints/model_1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 6.1258e-04
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012
# Epoch 100: val_loss did not improve from 0.00061
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 6.9996e-04
# Restoring model weights from the end of the best epoch: 99.
# Model training completed for bootstrap 1
# Generating predictions for validation set...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Bootstrap 3/100
# Creating and training model for bootstrap 2...
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0659
# Epoch 1: val_loss improved from inf to 0.00675, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0654 - val_loss: 0.0067
# Epoch 2/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0108
# Epoch 2: val_loss improved from 0.00675 to 0.00411, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0108 - val_loss: 0.0041
# Epoch 3/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0080
# Epoch 3: val_loss improved from 0.00411 to 0.00307, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0080 - val_loss: 0.0031
# Epoch 4/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0065
# Epoch 4: val_loss improved from 0.00307 to 0.00269, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 5/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0059
# Epoch 5: val_loss improved from 0.00269 to 0.00259, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0059 - val_loss: 0.0026
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051
# Epoch 6: val_loss improved from 0.00259 to 0.00211, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0051 - val_loss: 0.0021
# Epoch 7/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0046
# Epoch 7: val_loss improved from 0.00211 to 0.00185, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 8/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0041
# Epoch 8: val_loss improved from 0.00185 to 0.00166, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036
# Epoch 9: val_loss improved from 0.00166 to 0.00136, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 10/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034
# Epoch 10: val_loss did not improve from 0.00136
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 11/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034
# Epoch 11: val_loss improved from 0.00136 to 0.00125, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 12/100
# 76/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 12: val_loss did not improve from 0.00125
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 13/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 13: val_loss improved from 0.00125 to 0.00119, saving model to model_checkpoints/model_2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 14/100
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 14: val_loss did not improve from 0.00119
# ...
# Epoch 99/100
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0012
# Epoch 99: val_loss did not improve from 0.00052
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0012 - val_loss: 6.4123e-04
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0011
# Epoch 100: val_loss improved from 0.00052 to 0.00050, saving model to model_checkpoints/model_99.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0011 - val_loss: 5.0263e-04
# Restoring model weights from the end of the best epoch: 100.
# Model training completed for bootstrap 99
# Generating predictions for validation set...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 279ms/step
# Forecasts shape: (100, 38, 6)
# Calculating ensemble statistics...
# Saving forecast results to files...
# Results saved to forecast_results/forecast_results.pkl
# Bootstrap forecasting completed
# Transforming forecasts back to original scale...
# Mean forecast shape before transform: (38, 6)
# Lower bound shape before transform: (38, 6)
# Upper bound shape before transform: (38, 6)
# Mean forecast shape after transform: (38, 6)
# Lower bound shape after transform: (38, 6)
# Upper bound shape after transform: (38, 6)
# Computing actual values for validation period...
# Actual values shape: (38, 6)
# Calculating evaluation metrics...
#
# ===== EVALUATION METRICS =====
# Average RMSE: 5.9936
# Average PICP: 0.3728
# Average MPIW: 5.7592
# ==============================
#
# Preparing for future predictions...
# Forecasting 77 months ahead, until 2030
# Generating 77 future dates from 2024-07-01 00:00:00...
# Generating future forecasts with all models...
# Predicting future 77 months with model 0...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 0
# Predicting future 77 months with model 1...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 1
# Predicting future 77 months with model 2...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 2
# Predicting future 77 months with model 3...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 3
# Predicting future 77 months with model 4...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 4
# Predicting future 77 months with model 5...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 5
# Predicting future 77 months with model 6...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 6
# Predicting future 77 months with model 7...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 7
# Predicting future 77 months with model 8...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 8
# Predicting future 77 months with model 9...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 9
# Predicting future 77 months with model 10...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 10
# Predicting future 77 months with model 11...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 11
# Predicting future 77 months with model 12...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 12
# Predicting future 77 months with model 13...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 13
# Predicting future 77 months with model 14...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 14
# Predicting future 77 months with model 15...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 15
# Predicting future 77 months with model 16...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 16
# Predicting future 77 months with model 17...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 17
# Predicting future 77 months with model 18...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 18
# Predicting future 77 months with model 19...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 19
# Predicting future 77 months with model 20...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 20
# Predicting future 77 months with model 21...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 21
# Predicting future 77 months with model 22...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 22
# Predicting future 77 months with model 23...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 23
# Predicting future 77 months with model 24...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 24
# Predicting future 77 months with model 25...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 25
# Predicting future 77 months with model 26...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 26
# Predicting future 77 months with model 27...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 27
# Predicting future 77 months with model 28...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 28
# Predicting future 77 months with model 29...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 29
# Predicting future 77 months with model 30...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 30
# Predicting future 77 months with model 31...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 31
# Predicting future 77 months with model 32...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 32
# Predicting future 77 months with model 33...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 33
# Predicting future 77 months with model 34...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 34
# Predicting future 77 months with model 35...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 35
# Predicting future 77 months with model 36...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 36
# Predicting future 77 months with model 37...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 37
# Predicting future 77 months with model 38...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 38
# Predicting future 77 months with model 39...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 39
# Predicting future 77 months with model 40...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 40
# Predicting future 77 months with model 41...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 41
# Predicting future 77 months with model 42...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 42
# Predicting future 77 months with model 43...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 43
# Predicting future 77 months with model 44...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 44
# Predicting future 77 months with model 45...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 45
# Predicting future 77 months with model 46...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 46
# Predicting future 77 months with model 47...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 47
# Predicting future 77 months with model 48...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 48
# Predicting future 77 months with model 49...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 49
# Predicting future 77 months with model 50...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 50
# Predicting future 77 months with model 51...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 51
# Predicting future 77 months with model 52...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 52
# Predicting future 77 months with model 53...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 53
# Predicting future 77 months with model 54...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 54
# Predicting future 77 months with model 55...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 55
# Predicting future 77 months with model 56...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 56
# Predicting future 77 months with model 57...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 57
# Predicting future 77 months with model 58...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 58
# Predicting future 77 months with model 59...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 59
# Predicting future 77 months with model 60...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 60
# Predicting future 77 months with model 61...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 61
# Predicting future 77 months with model 62...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 62
# Predicting future 77 months with model 63...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 63
# Predicting future 77 months with model 64...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 64
# Predicting future 77 months with model 65...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 65
# Predicting future 77 months with model 66...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 66
# Predicting future 77 months with model 67...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 67
# Predicting future 77 months with model 68...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 68
# Predicting future 77 months with model 69...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 69
# Predicting future 77 months with model 70...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 70
# Predicting future 77 months with model 71...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 71
# Predicting future 77 months with model 72...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 72
# Predicting future 77 months with model 73...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 73
# Predicting future 77 months with model 74...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 74
# Predicting future 77 months with model 75...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 75
# Predicting future 77 months with model 76...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 76
# Predicting future 77 months with model 77...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 77
# Predicting future 77 months with model 78...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 78
# Predicting future 77 months with model 79...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 79
# Predicting future 77 months with model 80...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 80
# Predicting future 77 months with model 81...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 81
# Predicting future 77 months with model 82...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 82
# Predicting future 77 months with model 83...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 83
# Predicting future 77 months with model 84...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 84
# Predicting future 77 months with model 85...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 85
# Predicting future 77 months with model 86...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 86
# Predicting future 77 months with model 87...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 87
# Predicting future 77 months with model 88...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 88
# Predicting future 77 months with model 89...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 89
# Predicting future 77 months with model 90...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 90
# Predicting future 77 months with model 91...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 91
# Predicting future 77 months with model 92...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 92
# Predicting future 77 months with model 93...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 93
# Predicting future 77 months with model 94...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 94
# Predicting future 77 months with model 95...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 95
# Predicting future 77 months with model 96...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 96
# Predicting future 77 months with model 97...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 97
# Predicting future 77 months with model 98...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 98
# Predicting future 77 months with model 99...
# Completed 30/77 predictions
# Completed 60/77 predictions
# Future predictions completed for model 99
# Calculating ensemble statistics for future predictions...
# Future predictions saved to future_predictions.pkl
# Creating visualization...
# Forecasting process completed
