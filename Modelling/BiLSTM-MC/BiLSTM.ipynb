# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pickle

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
print("Checking for GPU availability...")
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print(f"GPU found: {physical_devices}")
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("Memory growth enabled for GPU")
else:
    print("No GPU found, using CPU")
# Out:
# Checking for GPU availability...
# GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Memory growth enabled for GPU

# %%
def load_data(file_path):
    print(f"Loading data from {file_path}...")
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
    df = df.set_index('date')
    print(f"Data loaded. Shape: {df.shape}")
    return df

# %%
def create_sequences(data, seq_length):
    print(f"Creating sequences with window size {seq_length}...")
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    print(f"Sequences created. X shape: {np.array(X).shape}, y shape: {np.array(y).shape}")
    return np.array(X), np.array(y)

# %%
def create_forecast_sequences(data, seq_length, forecast_horizon):
    print(f"Creating forecast sequences with window {seq_length} and horizon {forecast_horizon}...")
    X, y = [], []
    for i in range(len(data) - seq_length - forecast_horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length:i+seq_length+forecast_horizon])
    print(f"Forecast sequences created. X shape: {np.array(X).shape}, y shape: {np.array(y).shape}")
    return np.array(X), np.array(y)

# %%
def calculate_metrics(y_true, y_pred, y_lower, y_upper):
    # Ensure data consistency
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    y_lower = y_lower.flatten()
    y_upper = y_upper.flatten()

    # Check for NaN values
    assert not np.isnan(y_true).any(), "y_true contains NaNs"
    assert not np.isnan(y_pred).any(), "y_pred contains NaNs"

    # RMSE Calculation
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    # PICP Calculation
    within_interval = np.logical_and(y_true >= y_lower, y_true <= y_upper)
    picp = np.mean(within_interval)

    # MPIW Calculation
    mpiw = np.mean(y_upper - y_lower)

    return rmse, picp, mpiw

# %%
def create_train_model(X_train, y_train, forecast_horizon, model_dir):
    print("Creating and training MC Dropout model with BiLSTM...")
    
    os.makedirs(model_dir, exist_ok=True)
    
    model = Sequential([
        Bidirectional(LSTM(64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.2),
        Bidirectional(LSTM(32)),
        Dropout(0.2),
        Dense(forecast_horizon)
    ])

    model.compile(optimizer='adam', loss='mse')

    checkpoint_path = os.path.join(model_dir, "mc_dropout_model.keras")
    
    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        save_weights_only=False,
        verbose=1
    )
    
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    print("Model training completed")
    return model, history

# %%
def generate_mc_dropout_forecasts(X_train, y_train, X_val, forecast_horizon, num_samples=30, save_results=True):
    print(f"Generating Monte Carlo Dropout forecasts with {num_samples} samples...")
    
    # Directory for model checkpoints
    model_dir = "model_checkpoints"
    os.makedirs(model_dir, exist_ok=True)
    
    # Directory for results
    results_dir = "forecast_results"
    os.makedirs(results_dir, exist_ok=True)
    
    # Create and train model
    model, _ = create_train_model(X_train, y_train, forecast_horizon, model_dir)
    
    # Create MC Dropout prediction function
    class MCDropoutModel(tf.keras.Model):
        def __init__(self, model):
            super(MCDropoutModel, self).__init__()
            self.model = model
            
        def call(self, inputs, training=True):
            return self.model(inputs, training=True)
    
    mc_model = MCDropoutModel(model)
    
    # Generate multiple predictions with dropout enabled
    print(f"Generating {num_samples} MC Dropout predictions...")
    forecasts = []
    
    for i in range(num_samples):
        print(f"MC Dropout sample {i+1}/{num_samples}")
        forecast = mc_model.predict(X_val, verbose=0)
        forecasts.append(forecast)
    
    forecasts = np.array(forecasts)
    print(f"Forecasts shape: {forecasts.shape}")
    
    print("Calculating statistics...")
    mean_forecast = np.mean(forecasts, axis=0)
    lower_bound = np.quantile(forecasts, 0.05, axis=0)
    upper_bound = np.quantile(forecasts, 0.95, axis=0)
    
    # Save forecasts and bounds to files
    if save_results:
        print("Saving forecast results to files...")
        results = {
            'mean_forecast': mean_forecast,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound,
            'forecasts': forecasts
        }
        
        results_path = os.path.join(results_dir, 'forecast_results.pkl')
        with open(results_path, 'wb') as f:
            pickle.dump(results, f)
        
        print(f"Results saved to {results_path}")
    
    print("Monte Carlo Dropout forecasting completed")
    return mean_forecast, lower_bound, upper_bound, model, forecasts

# %%
def load_forecast_results(results_dir="forecast_results"):
    print("Loading forecast results from file...")
    results_path = os.path.join(results_dir, 'forecast_results.pkl')
    
    if not os.path.exists(results_path):
        raise FileNotFoundError(f"Results file not found at {results_path}")
    
    with open(results_path, 'rb') as f:
        results = pickle.load(f)
    
    print("Forecast results loaded successfully")
    return results['mean_forecast'], results['lower_bound'], results['upper_bound'], results['forecasts']

# %%
def load_trained_model(model_dir="model_checkpoints"):
    print(f"Loading trained model from {model_dir}...")
    
    if not os.path.exists(model_dir):
        raise FileNotFoundError(f"Model directory {model_dir} not found")
    
    model_path = os.path.join(model_dir, "mc_dropout_model.keras")
    if os.path.exists(model_path):
        model = load_model(model_path)
        print("Model loaded successfully")
        return model
    else:
        raise FileNotFoundError(f"Model file {model_path} not found")

# %%
def predict_future_mc_dropout(model, last_sequence, future_steps, forecast_horizon, scaler, num_samples=30):
    print(f"Predicting future {future_steps} months with MC Dropout ({num_samples} samples)...")
    
    # Create MC Dropout prediction function
    class MCDropoutModel(tf.keras.Model):
        def __init__(self, model):
            super(MCDropoutModel, self).__init__()
            self.model = model
            
        def call(self, inputs, training=True):
            return self.model(inputs, training=True)
    
    mc_model = MCDropoutModel(model)
    
    future_predictions_samples = []
    
    for sample in range(num_samples):
        future_predictions = []
        curr_sequence = last_sequence.copy()
        
        steps_completed = 0
        while steps_completed < future_steps:
            curr_sequence_reshaped = curr_sequence.reshape(1, curr_sequence.shape[0], curr_sequence.shape[1])
            
            # Predict next forecast_horizon steps with dropout enabled
            next_preds = mc_model.predict(curr_sequence_reshaped, verbose=0)[0]
            
            # Add as many predictions as needed
            steps_to_add = min(forecast_horizon, future_steps - steps_completed)
            future_predictions.extend(next_preds[:steps_to_add])
            
            # Update the sequence for the next iteration
            curr_sequence = np.roll(curr_sequence, -steps_to_add, axis=0)
            curr_sequence[-steps_to_add:] = next_preds[:steps_to_add].reshape(-1, 1)
            
            steps_completed += steps_to_add
        
        future_predictions = np.array(future_predictions).reshape(-1, 1)
        future_predictions_samples.append(future_predictions)
        
        if (sample + 1) % 5 == 0:
            print(f"Completed {sample + 1}/{num_samples} MC Dropout samples")
    
    future_predictions_samples = np.array(future_predictions_samples)
    
    # Calculate statistics
    future_mean = np.mean(future_predictions_samples, axis=0)
    future_lower = np.quantile(future_predictions_samples, 0.05, axis=0)
    future_upper = np.quantile(future_predictions_samples, 0.95, axis=0)
    
    # Transform back to original scale
    future_mean = scaler.inverse_transform(future_mean)
    future_lower = scaler.inverse_transform(future_lower)
    future_upper = scaler.inverse_transform(future_upper)
    
    print("Future predictions with MC Dropout completed")
    return future_mean, future_lower, future_upper

# %%
def generate_future_dates(last_date, num_months):
    print(f"Generating {num_months} future dates from {last_date}...")
    future_dates = pd.date_range(start=last_date, periods=num_months+1, freq='MS')[1:]
    return future_dates

# %%
def calculate_evaluation_metrics(actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv):
    rmse_values = []
    picp_values = []
    mpiw_values = []

    for i in range(len(actual_values)):
        rmse, picp, mpiw = calculate_metrics(
            actual_values[i],
            mean_forecast_inv[i],
            lower_bound_inv[i],
            upper_bound_inv[i]
        )
        rmse_values.append(rmse)
        picp_values.append(picp)
        mpiw_values.append(mpiw)

    print("\n===== EVALUATION METRICS =====")
    print(f"Average RMSE: {np.mean(rmse_values):.4f}")
    print(f"Average PICP: {np.mean(picp_values):.4f}")
    print(f"Average MPIW: {np.mean(mpiw_values):.4f}")
    print("==============================\n")
    
    return np.mean(rmse_values), np.mean(picp_values), np.mean(mpiw_values)

# %%
def plot_forecast(df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv, 
                 future_dates, future_mean, future_lower, future_upper,
                 cycle_24_start, cycle_25_start, forecast_horizon):
    start_date = pd.to_datetime('1996-01-01')
    plt.figure(figsize=(15, 8))

    # Historical data from 1996
    historical_mask = df.index >= start_date
    plt.plot(df.index[historical_mask], df['ssn'][historical_mask], 'b-', label='Historical Data')

    # Validation predictions with uncertainty
    for i in range(len(mean_forecast_inv)):
        pred_dates = val_dates[i:i+forecast_horizon]
        if len(pred_dates) == len(mean_forecast_inv[i]):
            plt.plot(pred_dates, mean_forecast_inv[i], 'r-', alpha=0.5, label='Validation Predictions' if i == 0 else "")
            plt.fill_between(pred_dates, lower_bound_inv[i], upper_bound_inv[i], color='r', alpha=0.2, label='90% Confidence Interval' if i == 0 else "")

    # Future forecasts
    plt.plot(future_dates, future_mean, 'g-', label='Future Predictions')
    plt.fill_between(future_dates, future_lower.flatten(), future_upper.flatten(), color='g', alpha=0.2, label='Future 90% Confidence Interval')
    plt.axvline(x=cycle_24_start, color='k', linestyle='--', label='Cycle 24 Start')
    plt.axvline(x=cycle_25_start, color='k', linestyle='--', label='Cycle 25 Start')
    plt.title('Sunspot Number Forecast with Uncertainty')
    plt.xlabel('Date')
    plt.ylabel('Sunspot Number')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    print("Starting sunspot forecasting process...")
    
    TRAIN_MODEL = True  # Set to False to load pre-trained model
    
    df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv')
    print("Data summary:")
    print(df.describe())

    print("Scaling data...")
    ssn = df['ssn'].values.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    ssn_scaled = scaler.fit_transform(ssn)
    print("Data scaling completed")
    
    # Save scaler for later use
    with open('scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    print("Defining cycle boundaries...")
    cycle_24_start = pd.to_datetime('2008-12-01')
    cycle_25_start = pd.to_datetime('2019-12-01')
    validation_start = pd.to_datetime('2021-01-01')

    print("Splitting data for training and validation...")
    train_data = ssn_scaled[df.index < cycle_25_start]
    val_data = ssn_scaled[(df.index >= validation_start)]
    val_dates = df.index[(df.index >= validation_start)]
    print(f"Training data points: {len(train_data)}")
    print(f"Validation data points: {len(val_data)}")

    # Define forecast horizon
    forecast_horizon = 6  # 6 months

    print("Creating training sequences...")
    seq_length = 8 * 12  # 8 years in months
    X_train, y_train = create_forecast_sequences(train_data, seq_length, forecast_horizon)
    print(f"Training sequences shape: {X_train.shape}, {y_train.shape}")

    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

    print("Creating validation sequences...")
    X_val = []
    y_val = []

    for i in range(len(val_dates) - forecast_horizon + 1):
        # Get the previous 8 years before the validation point
        start_idx = df.index.get_loc(val_dates[i]) - seq_length
        end_idx = df.index.get_loc(val_dates[i])
        forecast_end_idx = df.index.get_loc(val_dates[i]) + forecast_horizon

        if start_idx >= 0:
            X_val.append(ssn_scaled[start_idx:end_idx])
            y_val.append(ssn_scaled[end_idx:forecast_end_idx])

    X_val = np.array(X_val)
    y_val = np.array(y_val)

    # Reshape for LSTM
    X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
    print(f"Validation sequences shape: {X_val.shape}, {y_val.shape}")

    # Train or load model and generate MC Dropout samples
    num_samples = 100
    if TRAIN_MODEL:
        print("Starting Monte Carlo Dropout training and forecasting...")
        mean_forecast, lower_bound, upper_bound, model, forecasts = generate_mc_dropout_forecasts(
            X_train, y_train, X_val, forecast_horizon, num_samples=num_samples
        )
    else:
        print("Loading pre-trained model and forecast results...")
        mean_forecast, lower_bound, upper_bound, forecasts = load_forecast_results()
        model = load_trained_model()

    print("Transforming forecasts back to original scale...")
    # Reshape for inverse transform
    mean_forecast_reshaped = mean_forecast.reshape(-1, forecast_horizon)
    lower_bound_reshaped = lower_bound.reshape(-1, forecast_horizon)
    upper_bound_reshaped = upper_bound.reshape(-1, forecast_horizon)

    # Store original shapes for validation
    print(f"Mean forecast shape before transform: {mean_forecast_reshaped.shape}")
    print(f"Lower bound shape before transform: {lower_bound_reshaped.shape}")
    print(f"Upper bound shape before transform: {upper_bound_reshaped.shape}")

    # Transform back to original scale
    mean_forecast_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in mean_forecast_reshaped])
    lower_bound_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in lower_bound_reshaped])
    upper_bound_inv = np.array([scaler.inverse_transform(f.reshape(-1, 1)).flatten() for f in upper_bound_reshaped])

    print(f"Mean forecast shape after transform: {mean_forecast_inv.shape}")
    print(f"Lower bound shape after transform: {lower_bound_inv.shape}")
    print(f"Upper bound shape after transform: {upper_bound_inv.shape}")

    print("Computing actual values for validation period...")
    actual_values = []
    for i in range(len(y_val)):
        # Transform each sequence
        inv_y = scaler.inverse_transform(y_val[i].reshape(-1, 1)).flatten()
        actual_values.append(inv_y)

    actual_values = np.array(actual_values)
    print(f"Actual values shape: {actual_values.shape}")

    print("Calculating evaluation metrics...")
    avg_rmse, avg_picp, avg_mpiw = calculate_evaluation_metrics(
        actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv
    )

    print("Preparing for future predictions...")
    last_sequence = ssn_scaled[-seq_length:].reshape(seq_length, 1)
    last_date = df.index[-1]
    future_steps = (2030 - last_date.year) * 12 + (12 - last_date.month)
    print(f"Forecasting {future_steps} months ahead, until 2030")
    future_dates = generate_future_dates(last_date, future_steps)

    print("Generating future forecasts with MC Dropout...")
    future_mean, future_lower, future_upper = predict_future_mc_dropout(
        model, last_sequence, future_steps, forecast_horizon, scaler, num_samples=num_samples
    )

    # Save future predictions
    future_results = {
        'future_mean': future_mean,
        'future_lower': future_lower,
        'future_upper': future_upper,
        'future_dates': future_dates
    }
    with open('future_predictions.pkl', 'wb') as f:
        pickle.dump(future_results, f)
    print("Future predictions saved to future_predictions.pkl")

    print("Creating visualization...")
    plot_forecast(
        df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv,
        future_dates, future_mean, future_lower, future_upper,
        cycle_24_start, cycle_25_start, forecast_horizon
    )
    print("Forecasting process completed")
# Out:
# Starting sunspot forecasting process...
# Loading data from /Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv...
# Data loaded. Shape: (3301, 3)
# Data summary:
#                ssn         year        month
# count  3301.000000  3301.000000  3301.000000
# mean     81.844138  1886.541654     6.500151
# std      63.049151    79.422777     3.452063
# min       0.000000  1749.000000     1.000000
# 25%      25.700000  1818.000000     4.000000
# 50%      72.000000  1887.000000     7.000000
# 75%     119.600000  1955.000000     9.000000
# max     285.000000  2024.000000    12.000000
# Scaling data...
# Data scaling completed
# Defining cycle boundaries...
# Splitting data for training and validation...
# Training data points: 3245
# Validation data points: 43
# Creating training sequences...
# Creating forecast sequences with window 96 and horizon 6...
# Forecast sequences created. X shape: (3144, 96, 1), y shape: (3144, 6, 1)
# Training sequences shape: (3144, 96, 1), (3144, 6, 1)
# Creating validation sequences...
# Validation sequences shape: (38, 96, 1), (38, 6, 1)
# Starting Monte Carlo Dropout training and forecasting...
# Generating Monte Carlo Dropout forecasts with 100 samples...
# Creating and training MC Dropout model with BiLSTM...
# Epoch 1/100
# 2025-03-14 08:16:57.352603: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-03-14 08:16:57.352640: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-03-14 08:16:57.352668: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-03-14 08:16:57.352694: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-14 08:16:57.352709: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/envs/ssn/lib/python3.11/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-03-14 08:16:58.014232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0310
# Epoch 1: val_loss improved from inf to 0.00348, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - loss: 0.0308 - val_loss: 0.0035
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0056
# Epoch 2: val_loss improved from 0.00348 to 0.00233, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0044
# Epoch 3: val_loss improved from 0.00233 to 0.00190, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0039
# Epoch 4: val_loss did not improve from 0.00190
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0035
# Epoch 5: val_loss improved from 0.00190 to 0.00161, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0033
# Epoch 6: val_loss improved from 0.00161 to 0.00145, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0028
# Epoch 7: val_loss improved from 0.00145 to 0.00129, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0027
# Epoch 8: val_loss did not improve from 0.00129
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0026
# Epoch 9: val_loss improved from 0.00129 to 0.00124, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0023
# Epoch 10: val_loss improved from 0.00124 to 0.00123, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0023
# Epoch 11: val_loss improved from 0.00123 to 0.00108, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0023
# Epoch 12: val_loss did not improve from 0.00108
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0021
# Epoch 13: val_loss improved from 0.00108 to 0.00108, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0020
# Epoch 14: val_loss improved from 0.00108 to 0.00108, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0019
# Epoch 15: val_loss improved from 0.00108 to 0.00105, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017
# Epoch 16: val_loss did not improve from 0.00105
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0019
# Epoch 17: val_loss did not improve from 0.00105
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0018
# Epoch 18: val_loss did not improve from 0.00105
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0017
# Epoch 19: val_loss improved from 0.00105 to 0.00095, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0017 - val_loss: 9.5209e-04
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0019
# Epoch 20: val_loss did not improve from 0.00095
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017
# Epoch 21: val_loss improved from 0.00095 to 0.00090, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0017 - val_loss: 8.9890e-04
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0017
# Epoch 22: val_loss improved from 0.00090 to 0.00081, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - loss: 0.0017 - val_loss: 8.1124e-04
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0016
# Epoch 23: val_loss did not improve from 0.00081
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - loss: 0.0016 - val_loss: 8.8614e-04
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016
# Epoch 24: val_loss did not improve from 0.00081
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0016 - val_loss: 9.9903e-04
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016
# Epoch 25: val_loss improved from 0.00081 to 0.00081, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0016 - val_loss: 8.1046e-04
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016
# Epoch 26: val_loss improved from 0.00081 to 0.00079, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0016 - val_loss: 7.8716e-04
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0016
# Epoch 27: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0016 - val_loss: 7.9260e-04
# Epoch 28/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0015
# Epoch 28: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0015 - val_loss: 9.1152e-04
# Epoch 29/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0015
# Epoch 29: val_loss did not improve from 0.00079
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - loss: 0.0015 - val_loss: 8.6701e-04
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0014
# Epoch 30: val_loss improved from 0.00079 to 0.00072, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0014 - val_loss: 7.1825e-04
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0014
# Epoch 31: val_loss did not improve from 0.00072
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0014 - val_loss: 7.5538e-04
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0014
# Epoch 32: val_loss did not improve from 0.00072
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0014
# Epoch 33: val_loss did not improve from 0.00072
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0014 - val_loss: 8.0058e-04
# Epoch 34/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0016
# Epoch 34: val_loss did not improve from 0.00072
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 35/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0013
# Epoch 35: val_loss did not improve from 0.00072
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0013 - val_loss: 7.4257e-04
# Epoch 36/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0014
# Epoch 36: val_loss improved from 0.00072 to 0.00069, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0014 - val_loss: 6.8983e-04
# Epoch 37/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0013
# Epoch 37: val_loss improved from 0.00069 to 0.00067, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0013 - val_loss: 6.7245e-04
# Epoch 38/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0013
# Epoch 38: val_loss improved from 0.00067 to 0.00064, saving model to model_checkpoints/mc_dropout_model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0013 - val_loss: 6.3626e-04
# Epoch 39/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0013
# Epoch 39: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0013 - val_loss: 7.3444e-04
# Epoch 40/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0012
# Epoch 40: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0012 - val_loss: 7.0288e-04
# Epoch 41/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0014
# Epoch 41: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0014 - val_loss: 6.9043e-04
# Epoch 42/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0013
# Epoch 42: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0013 - val_loss: 7.7524e-04
# Epoch 43/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0015
# Epoch 43: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0015 - val_loss: 7.3656e-04
# Epoch 44/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0014
# Epoch 44: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0014 - val_loss: 7.3761e-04
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0013
# Epoch 45: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - loss: 0.0013 - val_loss: 7.8240e-04
# Epoch 46/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0013
# Epoch 46: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0013 - val_loss: 6.4723e-04
# Epoch 47/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0013
# Epoch 47: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 0.0013 - val_loss: 9.0009e-04
# Epoch 48/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0013
# Epoch 48: val_loss did not improve from 0.00064
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - loss: 0.0013 - val_loss: 7.2140e-04
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.
# Model training completed
# Generating 100 MC Dropout predictions...
# MC Dropout sample 1/100
# MC Dropout sample 2/100
# MC Dropout sample 3/100
# MC Dropout sample 4/100
# MC Dropout sample 5/100
# MC Dropout sample 6/100
# MC Dropout sample 7/100
# MC Dropout sample 8/100
# MC Dropout sample 9/100
# MC Dropout sample 10/100
# MC Dropout sample 11/100
# MC Dropout sample 12/100
# MC Dropout sample 13/100
# MC Dropout sample 14/100
# MC Dropout sample 15/100
# MC Dropout sample 16/100
# MC Dropout sample 17/100
# MC Dropout sample 18/100
# MC Dropout sample 19/100
# MC Dropout sample 20/100
# MC Dropout sample 21/100
# MC Dropout sample 22/100
# MC Dropout sample 23/100
# MC Dropout sample 24/100
# MC Dropout sample 25/100
# MC Dropout sample 26/100
# MC Dropout sample 27/100
# MC Dropout sample 28/100
# MC Dropout sample 29/100
# MC Dropout sample 30/100
# MC Dropout sample 31/100
# MC Dropout sample 32/100
# MC Dropout sample 33/100
# MC Dropout sample 34/100
# MC Dropout sample 35/100
# MC Dropout sample 36/100
# MC Dropout sample 37/100
# MC Dropout sample 38/100
# MC Dropout sample 39/100
# MC Dropout sample 40/100
# MC Dropout sample 41/100
# MC Dropout sample 42/100
# MC Dropout sample 43/100
# MC Dropout sample 44/100
# MC Dropout sample 45/100
# MC Dropout sample 46/100
# MC Dropout sample 47/100
# MC Dropout sample 48/100
# MC Dropout sample 49/100
# MC Dropout sample 50/100
# MC Dropout sample 51/100
# MC Dropout sample 52/100
# MC Dropout sample 53/100
# MC Dropout sample 54/100
# MC Dropout sample 55/100
# MC Dropout sample 56/100
# MC Dropout sample 57/100
# MC Dropout sample 58/100
# MC Dropout sample 59/100
# MC Dropout sample 60/100
# MC Dropout sample 61/100
# MC Dropout sample 62/100
# MC Dropout sample 63/100
# MC Dropout sample 64/100
# MC Dropout sample 65/100
# MC Dropout sample 66/100
# MC Dropout sample 67/100
# MC Dropout sample 68/100
# MC Dropout sample 69/100
# MC Dropout sample 70/100
# MC Dropout sample 71/100
# MC Dropout sample 72/100
# MC Dropout sample 73/100
# MC Dropout sample 74/100
# MC Dropout sample 75/100
# MC Dropout sample 76/100
# MC Dropout sample 77/100
# MC Dropout sample 78/100
# MC Dropout sample 79/100
# MC Dropout sample 80/100
# MC Dropout sample 81/100
# MC Dropout sample 82/100
# MC Dropout sample 83/100
# MC Dropout sample 84/100
# MC Dropout sample 85/100
# MC Dropout sample 86/100
# MC Dropout sample 87/100
# MC Dropout sample 88/100
# MC Dropout sample 89/100
# MC Dropout sample 90/100
# MC Dropout sample 91/100
# MC Dropout sample 92/100
# MC Dropout sample 93/100
# MC Dropout sample 94/100
# MC Dropout sample 95/100
# MC Dropout sample 96/100
# MC Dropout sample 97/100
# MC Dropout sample 98/100
# MC Dropout sample 99/100
# MC Dropout sample 100/100
# Forecasts shape: (100, 38, 6)
# Calculating statistics...
# Saving forecast results to files...
# Results saved to forecast_results/forecast_results.pkl
# Monte Carlo Dropout forecasting completed
# Transforming forecasts back to original scale...
# Mean forecast shape before transform: (38, 6)
# Lower bound shape before transform: (38, 6)
# Upper bound shape before transform: (38, 6)
# Mean forecast shape after transform: (38, 6)
# Lower bound shape after transform: (38, 6)
# Upper bound shape after transform: (38, 6)
# Computing actual values for validation period...
# Actual values shape: (38, 6)
# Calculating evaluation metrics...
#
# ===== EVALUATION METRICS =====
# Average RMSE: 5.8311
# Average PICP: 0.7763
# Average MPIW: 15.4501
# ==============================
#
# Preparing for future predictions...
# Forecasting 77 months ahead, until 2030
# Generating 77 future dates from 2024-07-01 00:00:00...
# Generating future forecasts with MC Dropout...
# Predicting future 77 months with MC Dropout (100 samples)...
# Completed 5/100 MC Dropout samples
# Completed 10/100 MC Dropout samples
# Completed 15/100 MC Dropout samples
# Completed 20/100 MC Dropout samples
# Completed 25/100 MC Dropout samples
# Completed 30/100 MC Dropout samples
# Completed 35/100 MC Dropout samples
# Completed 40/100 MC Dropout samples
# Completed 45/100 MC Dropout samples
# Completed 50/100 MC Dropout samples
# Completed 55/100 MC Dropout samples
# Completed 60/100 MC Dropout samples
# Completed 65/100 MC Dropout samples
# Completed 70/100 MC Dropout samples
# Completed 75/100 MC Dropout samples
# Completed 80/100 MC Dropout samples
# Completed 85/100 MC Dropout samples
# Completed 90/100 MC Dropout samples
# Completed 95/100 MC Dropout samples
# Completed 100/100 MC Dropout samples
# Future predictions with MC Dropout completed
# Future predictions saved to future_predictions.pkl
# Creating visualization...
# Forecasting process completed
