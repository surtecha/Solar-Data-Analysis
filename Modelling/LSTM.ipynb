# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import math
from datetime import datetime, timedelta

# Set random seed for reproducibility
np.random.seed(42)

# 1. Data Preparation
# Load the data from the existing CSV file
df = pd.read_csv('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv')

# Convert year and month to datetime
df['date'] = pd.to_datetime(df[['year', 'month']].assign(DAY=1))
df = df.drop(['year', 'month'], axis=1)

# Filter training data to include only records until the end of 2019
train_df = df[df['date'] < '2020-01-01'].copy()
print(f"Training data shape: {train_df.shape}")

# Scale the SSN values
scaler = MinMaxScaler(feature_range=(0, 1))
ssn_scaled = scaler.fit_transform(train_df['ssn'].values.reshape(-1, 1))

# Function to create sequences
def create_sequences(data, window_size=72):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

# Create sequences
X, y = create_sequences(ssn_scaled)
print(f"Sequence data shape: X={X.shape}, y={y.shape}")

# Create sample weights to reduce influence of 24th cycle
# 24th cycle approximately spans from 2008 to 2019
weights = np.ones(len(X))
for i in range(len(X)):
    seq_date = train_df['date'].iloc[i+72]  # Date of the target point
    if '2008-01-01' <= str(seq_date) <= '2019-12-31':
        weights[i] = 0.5  # Lower weight for 24th cycle

# Split data into training and validation sets (80% train, 20% validation)
train_size = int(len(X) * 0.8)
X_train, X_val = X[:train_size], X[train_size:]
y_train, y_val = y[:train_size], y[train_size:]
weights_train = weights[:train_size]

print(f"Training set: X_train={X_train.shape}, y_train={y_train.shape}")
print(f"Validation set: X_val={X_val.shape}, y_val={y_val.shape}")

# 2. Model Architecture
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(72, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mse')
model.summary()

# 3. Training Process
# Reshape inputs to [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# Implement callbacks
checkpoint = ModelCheckpoint('ssn_forecast_model.keras', 
                            monitor='val_loss', 
                            save_best_only=True, 
                            mode='min', 
                            verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', 
                              patience=10, 
                              restore_best_weights=True, 
                              verbose=1)

# Train the model
history = model.fit(X_train, y_train, 
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_val, y_val), 
                    callbacks=[checkpoint, early_stopping], 
                    sample_weight=weights_train,
                    verbose=1)

# 4. Evaluation and Visualization
# Plot training metrics
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Load the best model
model = load_model('ssn_forecast_model.keras')

# Make predictions on the validation set
y_val_pred = model.predict(X_val)

# Inverse transform the scaled values
y_val_orig = scaler.inverse_transform(y_val.reshape(-1, 1))
y_val_pred_orig = scaler.inverse_transform(y_val_pred)

# Calculate metrics
val_rmse = np.sqrt(mean_squared_error(y_val_orig, y_val_pred_orig))
val_mae = mean_absolute_error(y_val_orig, y_val_pred_orig)
val_r2 = r2_score(y_val_orig, y_val_pred_orig)

print(f"Validation Metrics:")
print(f"RMSE: {val_rmse:.2f}")
print(f"MAE: {val_mae:.2f}")
print(f"R²: {val_r2:.4f}")

# Get dates for validation set visualization
val_dates = train_df['date'].iloc[train_size+72:train_size+72+len(y_val)]

# Plot actual vs. predicted values for validation set
plt.figure(figsize=(14, 7))
plt.plot(val_dates, y_val_orig, label='Actual SSN')
plt.plot(val_dates, y_val_pred_orig, label='Predicted SSN')
plt.title('Validation Set: Actual vs Predicted Sunspot Numbers')
plt.xlabel('Date')
plt.ylabel('Sunspot Number')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 5. Generate future forecast until 2030
# Get the most recent 72 months of data
recent_data = df[df['date'] <= '2019-12-01'].tail(72)
recent_dates = recent_data['date'].values
last_date = recent_dates[-1]

# Scale the recent data
recent_values = scaler.transform(recent_data['ssn'].values.reshape(-1, 1))
input_seq = recent_values.reshape(1, 72, 1)  # Shape: (1, 72, 1)

# Create date range for forecast
forecast_start = pd.to_datetime(last_date) + pd.DateOffset(months=1)
forecast_end = pd.to_datetime('2030-12-01')
forecast_dates = pd.date_range(start=forecast_start, end=forecast_end, freq='MS')
forecast_length = len(forecast_dates)

# Generate predictions
forecast = []
curr_seq = input_seq.copy()

for _ in range(forecast_length):
    # Get prediction for next month
    next_pred = model.predict(curr_seq)[0, 0]  # Extract the scalar value
    forecast.append(next_pred)
    
    # Update sequence - correctly handling the dimensions
    curr_seq = np.roll(curr_seq, -1, axis=1)  # Shift values to the left
    curr_seq[0, -1, 0] = next_pred  # Set the last value to the new prediction

# Convert to numpy array and inverse transform
forecast = np.array(forecast).reshape(-1, 1)
forecast = scaler.inverse_transform(forecast)

# 6. Plot results
# Create a figure showing historical and forecasted SSN
plt.figure(figsize=(16, 8))

# Plot historical data from 1996 onwards
historical_data = df[df['date'] >= '1996-01-01']
plt.plot(historical_data['date'], historical_data['ssn'], 'b-', label='Historical SSN')

# Plot forecast
plt.plot(forecast_dates, forecast, 'r-', label='Forecasted SSN (2020-2030)')

# Add vertical line to indicate forecast start
forecast_start_date = pd.to_datetime('2020-01-01')
plt.axvline(x=forecast_start_date, color='k', linestyle='--', label='Forecast Start')

plt.title('Sunspot Number (SSN) Historical Data and Forecast', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Sunspot Number', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# 7. Calculate full dataset performance metrics
# Make predictions on the full dataset
X_full = X.reshape((X.shape[0], X.shape[1], 1))
y_full_pred = model.predict(X_full)

# Inverse transform
y_full_orig = scaler.inverse_transform(y.reshape(-1, 1))
y_full_pred_orig = scaler.inverse_transform(y_full_pred)

# Calculate metrics
full_rmse = np.sqrt(mean_squared_error(y_full_orig, y_full_pred_orig))
full_mae = mean_absolute_error(y_full_orig, y_full_pred_orig)
full_r2 = r2_score(y_full_orig, y_full_pred_orig)

print(f"\nFull Dataset Performance Metrics:")
print(f"RMSE: {full_rmse:.2f}")
print(f"MAE: {full_mae:.2f}")
print(f"R²: {full_r2:.4f}")

# Display a comparison of actual vs predicted values for the full training dataset
full_dates = train_df['date'].iloc[72:72+len(y)]

plt.figure(figsize=(14, 7))
plt.plot(full_dates, y_full_orig, label='Actual SSN')
plt.plot(full_dates, y_full_pred_orig, label='Predicted SSN')
plt.title('Full Dataset: Actual vs Predicted Sunspot Numbers')
plt.xlabel('Date')
plt.ylabel('Sunspot Number')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print("Model saved as 'ssn_forecast_model.keras'")
# Out:
# Training data shape: (3246, 2)
# Sequence data shape: X=(3174, 72, 1), y=(3174, 1)
# Training set: X_train=(2539, 72, 1), y_train=(2539, 1)
# Validation set: X_val=(635, 72, 1), y_val=(635, 1)
# /opt/anaconda3/envs/ssn/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 72, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 72, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0321
# Epoch 1: val_loss improved from inf to 0.00239, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0315 - val_loss: 0.0024
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039
# Epoch 2: val_loss improved from 0.00239 to 0.00158, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 3/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 3: val_loss did not improve from 0.00158
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 4/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 4: val_loss improved from 0.00158 to 0.00106, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 5/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020
# Epoch 5: val_loss improved from 0.00106 to 0.00097, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0020 - val_loss: 9.7392e-04
# Epoch 6/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019
# Epoch 6: val_loss improved from 0.00097 to 0.00097, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0019 - val_loss: 9.6892e-04
# Epoch 7/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018
# Epoch 7: val_loss improved from 0.00097 to 0.00081, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0018 - val_loss: 8.0505e-04
# Epoch 8/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0016
# Epoch 8: val_loss did not improve from 0.00081
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 9/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019
# Epoch 9: val_loss improved from 0.00081 to 0.00059, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0019 - val_loss: 5.9256e-04
# Epoch 10/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0015
# Epoch 10: val_loss improved from 0.00059 to 0.00051, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0015 - val_loss: 5.1153e-04
# Epoch 11/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0013
# Epoch 11: val_loss improved from 0.00051 to 0.00044, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 4.4061e-04
# Epoch 12/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0013
# Epoch 12: val_loss did not improve from 0.00044
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - val_loss: 5.9148e-04
# Epoch 13/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012
# Epoch 13: val_loss did not improve from 0.00044
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0012 - val_loss: 6.0918e-04
# Epoch 14/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0012
# Epoch 14: val_loss improved from 0.00044 to 0.00041, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0012 - val_loss: 4.1148e-04
# Epoch 15/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011
# Epoch 15: val_loss did not improve from 0.00041
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0011 - val_loss: 4.8863e-04
# Epoch 16/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011
# Epoch 16: val_loss improved from 0.00041 to 0.00030, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0011 - val_loss: 2.9818e-04
# Epoch 17/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010
# Epoch 17: val_loss did not improve from 0.00030
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0010 - val_loss: 3.7199e-04
# Epoch 18/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0010
# Epoch 18: val_loss improved from 0.00030 to 0.00026, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0010 - val_loss: 2.6458e-04
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4950e-04
# Epoch 19: val_loss improved from 0.00026 to 0.00026, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.5028e-04 - val_loss: 2.5534e-04
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7691e-04
# Epoch 20: val_loss did not improve from 0.00026
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.7693e-04 - val_loss: 4.1708e-04
# Epoch 21/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.3871e-04
# Epoch 21: val_loss improved from 0.00026 to 0.00025, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.3839e-04 - val_loss: 2.4922e-04
# Epoch 22/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.6362e-04
# Epoch 22: val_loss did not improve from 0.00025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6311e-04 - val_loss: 5.5936e-04
# Epoch 23/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.0803e-04
# Epoch 23: val_loss did not improve from 0.00025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0721e-04 - val_loss: 3.4541e-04
# Epoch 24/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.8505e-04
# Epoch 24: val_loss did not improve from 0.00025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.8580e-04 - val_loss: 2.5056e-04
# Epoch 25/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.5303e-04
# Epoch 25: val_loss improved from 0.00025 to 0.00024, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.4937e-04 - val_loss: 2.4247e-04
# Epoch 26/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1944e-04
# Epoch 26: val_loss did not improve from 0.00024
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.2100e-04 - val_loss: 2.9377e-04
# Epoch 27/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.8503e-04
# Epoch 27: val_loss improved from 0.00024 to 0.00024, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.8424e-04 - val_loss: 2.3530e-04
# Epoch 28/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4152e-04
# Epoch 28: val_loss did not improve from 0.00024
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4001e-04 - val_loss: 2.6094e-04
# Epoch 29/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9272e-04
# Epoch 29: val_loss improved from 0.00024 to 0.00023, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.9248e-04 - val_loss: 2.3120e-04
# Epoch 30/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0976e-04
# Epoch 30: val_loss improved from 0.00023 to 0.00023, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0873e-04 - val_loss: 2.2991e-04
# Epoch 31/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9235e-04
# Epoch 31: val_loss improved from 0.00023 to 0.00022, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.9329e-04 - val_loss: 2.2189e-04
# Epoch 32/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3806e-04
# Epoch 32: val_loss improved from 0.00022 to 0.00021, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 8.3654e-04 - val_loss: 2.0608e-04
# Epoch 33/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7252e-04
# Epoch 33: val_loss did not improve from 0.00021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.7125e-04 - val_loss: 2.5520e-04
# Epoch 34/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9103e-04
# Epoch 34: val_loss did not improve from 0.00021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.9002e-04 - val_loss: 2.0623e-04
# Epoch 35/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.3441e-04
# Epoch 35: val_loss did not improve from 0.00021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3301e-04 - val_loss: 2.5843e-04
# Epoch 36/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.4791e-04
# Epoch 36: val_loss did not improve from 0.00021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5054e-04 - val_loss: 2.2166e-04
# Epoch 37/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.8325e-04
# Epoch 37: val_loss did not improve from 0.00021
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.8551e-04 - val_loss: 2.9456e-04
# Epoch 38/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1071e-04
# Epoch 38: val_loss improved from 0.00021 to 0.00019, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0932e-04 - val_loss: 1.9014e-04
# Epoch 39/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9200e-04
# Epoch 39: val_loss did not improve from 0.00019
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.9192e-04 - val_loss: 3.0085e-04
# Epoch 40/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2170e-04
# Epoch 40: val_loss did not improve from 0.00019
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.2009e-04 - val_loss: 2.4122e-04
# Epoch 41/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6785e-04
# Epoch 41: val_loss did not improve from 0.00019
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.6702e-04 - val_loss: 2.2509e-04
# Epoch 42/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.7561e-04
# Epoch 42: val_loss did not improve from 0.00019
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.7480e-04 - val_loss: 2.1473e-04
# Epoch 43/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5070e-04
# Epoch 43: val_loss improved from 0.00019 to 0.00019, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 7.4482e-04 - val_loss: 1.8608e-04
# Epoch 44/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.3080e-04
# Epoch 44: val_loss did not improve from 0.00019
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3164e-04 - val_loss: 2.6310e-04
# Epoch 45/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.3228e-04
# Epoch 45: val_loss improved from 0.00019 to 0.00017, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3356e-04 - val_loss: 1.7442e-04
# Epoch 46/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.9519e-04
# Epoch 46: val_loss did not improve from 0.00017
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.9328e-04 - val_loss: 3.3585e-04
# Epoch 47/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.5655e-04
# Epoch 47: val_loss did not improve from 0.00017
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.5334e-04 - val_loss: 1.8303e-04
# Epoch 48/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.2848e-04
# Epoch 48: val_loss did not improve from 0.00017
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.2870e-04 - val_loss: 1.7719e-04
# Epoch 49/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.6166e-04
# Epoch 49: val_loss improved from 0.00017 to 0.00015, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.6345e-04 - val_loss: 1.4842e-04
# Epoch 50/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.7980e-04
# Epoch 50: val_loss did not improve from 0.00015
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7901e-04 - val_loss: 1.4899e-04
# Epoch 51/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.6594e-04
# Epoch 51: val_loss did not improve from 0.00015
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.6570e-04 - val_loss: 1.7972e-04
# Epoch 52/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5289e-04
# Epoch 52: val_loss did not improve from 0.00015
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.5184e-04 - val_loss: 1.5258e-04
# Epoch 53/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4731e-04
# Epoch 53: val_loss did not improve from 0.00015
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4763e-04 - val_loss: 1.6389e-04
# Epoch 54/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.7457e-04
# Epoch 54: val_loss improved from 0.00015 to 0.00013, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7422e-04 - val_loss: 1.3036e-04
# Epoch 55/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1519e-04
# Epoch 55: val_loss did not improve from 0.00013
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1769e-04 - val_loss: 1.7910e-04
# Epoch 56/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.5642e-04
# Epoch 56: val_loss improved from 0.00013 to 0.00013, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.5688e-04 - val_loss: 1.2567e-04
# Epoch 57/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1470e-04
# Epoch 57: val_loss did not improve from 0.00013
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1518e-04 - val_loss: 1.6758e-04
# Epoch 58/100
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.6750e-04
# Epoch 58: val_loss improved from 0.00013 to 0.00012, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.6604e-04 - val_loss: 1.1603e-04
# Epoch 59/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0155e-04
# Epoch 59: val_loss did not improve from 0.00012
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0284e-04 - val_loss: 3.3838e-04
# Epoch 60/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9434e-04
# Epoch 60: val_loss did not improve from 0.00012
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9473e-04 - val_loss: 1.2237e-04
# Epoch 61/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.8883e-04
# Epoch 61: val_loss improved from 0.00012 to 0.00011, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8960e-04 - val_loss: 1.1347e-04
# Epoch 62/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.1692e-04
# Epoch 62: val_loss improved from 0.00011 to 0.00011, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1605e-04 - val_loss: 1.0940e-04
# Epoch 63/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.7000e-04
# Epoch 63: val_loss improved from 0.00011 to 0.00010, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.7031e-04 - val_loss: 1.0162e-04
# Epoch 64/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1382e-04
# Epoch 64: val_loss did not improve from 0.00010
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1295e-04 - val_loss: 1.9525e-04
# Epoch 65/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4435e-04
# Epoch 65: val_loss improved from 0.00010 to 0.00010, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4394e-04 - val_loss: 1.0078e-04
# Epoch 66/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5683e-04
# Epoch 66: val_loss improved from 0.00010 to 0.00009, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.5807e-04 - val_loss: 9.1605e-05
# Epoch 67/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.3881e-04
# Epoch 67: val_loss did not improve from 0.00009
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.4085e-04 - val_loss: 1.8407e-04
# Epoch 68/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6831e-04
# Epoch 68: val_loss did not improve from 0.00009
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6849e-04 - val_loss: 1.4361e-04
# Epoch 69/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3347e-04
# Epoch 69: val_loss did not improve from 0.00009
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3459e-04 - val_loss: 1.3538e-04
# Epoch 70/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5774e-04
# Epoch 70: val_loss improved from 0.00009 to 0.00008, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.5847e-04 - val_loss: 8.2015e-05
# Epoch 71/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6709e-04
# Epoch 71: val_loss did not improve from 0.00008
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.6827e-04 - val_loss: 2.3398e-04
# Epoch 72/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8685e-04
# Epoch 72: val_loss improved from 0.00008 to 0.00008, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8615e-04 - val_loss: 8.1016e-05
# Epoch 73/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6031e-04
# Epoch 73: val_loss did not improve from 0.00008
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6057e-04 - val_loss: 1.5600e-04
# Epoch 74/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5208e-04
# Epoch 74: val_loss did not improve from 0.00008
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.5145e-04 - val_loss: 1.6019e-04
# Epoch 75/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1771e-04
# Epoch 75: val_loss did not improve from 0.00008
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1869e-04 - val_loss: 1.6190e-04
# Epoch 76/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6947e-04
# Epoch 76: val_loss did not improve from 0.00008
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6918e-04 - val_loss: 1.0904e-04
# Epoch 77/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9270e-04
# Epoch 77: val_loss improved from 0.00008 to 0.00008, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9197e-04 - val_loss: 7.7988e-05
# Epoch 78/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5606e-04
# Epoch 78: val_loss improved from 0.00008 to 0.00007, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.5583e-04 - val_loss: 7.0237e-05
# Epoch 79/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0284e-04
# Epoch 79: val_loss did not improve from 0.00007
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0272e-04 - val_loss: 7.8500e-05
# Epoch 80/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6122e-04
# Epoch 80: val_loss did not improve from 0.00007
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6104e-04 - val_loss: 1.8302e-04
# Epoch 81/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1453e-04
# Epoch 81: val_loss improved from 0.00007 to 0.00006, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.1293e-04 - val_loss: 6.0178e-05
# Epoch 82/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6229e-04
# Epoch 82: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.6341e-04 - val_loss: 1.2982e-04
# Epoch 83/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1307e-04
# Epoch 83: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.1254e-04 - val_loss: 6.4193e-05
# Epoch 84/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8808e-04
# Epoch 84: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8898e-04 - val_loss: 1.3159e-04
# Epoch 85/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8585e-04
# Epoch 85: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.8648e-04 - val_loss: 2.5324e-04
# Epoch 86/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0326e-04
# Epoch 86: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 5.0091e-04 - val_loss: 1.6240e-04
# Epoch 87/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.7047e-04
# Epoch 87: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.7092e-04 - val_loss: 6.4552e-05
# Epoch 88/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8877e-04
# Epoch 88: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8877e-04 - val_loss: 6.1607e-05
# Epoch 89/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3676e-04
# Epoch 89: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3653e-04 - val_loss: 7.6540e-05
# Epoch 90/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8799e-04
# Epoch 90: val_loss improved from 0.00006 to 0.00006, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.8695e-04 - val_loss: 5.5435e-05
# Epoch 91/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.4534e-04
# Epoch 91: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.4322e-04 - val_loss: 6.9831e-05
# Epoch 92/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9350e-04
# Epoch 92: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9293e-04 - val_loss: 8.4545e-05
# Epoch 93/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5870e-04
# Epoch 93: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.5817e-04 - val_loss: 8.1066e-05
# Epoch 94/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3762e-04
# Epoch 94: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3821e-04 - val_loss: 2.8728e-04
# Epoch 95/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9296e-04
# Epoch 95: val_loss did not improve from 0.00006
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.9300e-04 - val_loss: 2.1883e-04
# Epoch 96/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5767e-04
# Epoch 96: val_loss improved from 0.00006 to 0.00005, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.5703e-04 - val_loss: 5.2530e-05
# Epoch 97/100
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1567e-04
# Epoch 97: val_loss did not improve from 0.00005
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.1692e-04 - val_loss: 1.3054e-04
# Epoch 98/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.3228e-04
# Epoch 98: val_loss did not improve from 0.00005
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.3263e-04 - val_loss: 9.5832e-05
# Epoch 99/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6275e-04
# Epoch 99: val_loss improved from 0.00005 to 0.00005, saving model to ssn_forecast_model.keras
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.6223e-04 - val_loss: 4.8122e-05
# Epoch 100/100
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.8409e-04
# Epoch 100: val_loss did not improve from 0.00005
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.8371e-04 - val_loss: 4.9635e-05
# Restoring model weights from the end of the best epoch: 99.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Validation Metrics:
# RMSE: 1.98
# MAE: 1.47
# R²: 0.9991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Full Dataset Performance Metrics:
# RMSE: 2.11
# MAE: 1.55
# R²: 0.9989
# Model saved as 'ssn_forecast_model.keras'
