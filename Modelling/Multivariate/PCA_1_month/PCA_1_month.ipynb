# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
import os
import pickle

np.random.seed(42)
tf.random.set_seed(42)

# Configure GPU if available
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

def load_data(file_path):
    """Load and prepare data from CSV files"""
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
    df = df.set_index('date')
    return df

def create_forecast_sequences(data, seq_length, forecast_horizon):
    """Create input-output sequences for forecasting"""
    X, y = [], []
    for i in range(len(data) - seq_length - forecast_horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length:i+seq_length+forecast_horizon])
    return np.array(X), np.array(y)

def calculate_metrics(y_true, y_pred, y_lower, y_upper):
    """Calculate evaluation metrics for forecasts"""
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    y_lower = y_lower.flatten()
    y_upper = y_upper.flatten()
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    within_interval = np.logical_and(y_true >= y_lower, y_true <= y_upper)
    picp = np.mean(within_interval)  # Prediction Interval Coverage Probability
    mpiw = np.mean(y_upper - y_lower)  # Mean Prediction Interval Width
    
    return rmse, picp, mpiw

def create_train_model(X_train, y_train, forecast_horizon, n_features, model_dir, bootstrap_id):
    """Create and train LSTM model"""
    os.makedirs(model_dir, exist_ok=True)
    
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], n_features)),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(forecast_horizon * n_features)  # Output forecasts for all principal components
    ])

    model.compile(optimizer='adam', loss='mse')

    checkpoint_path = os.path.join(model_dir, f"pca_model_{bootstrap_id}.keras")
    
    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        save_weights_only=False,
        verbose=1
    )
    
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    return model, history

def generate_bootstrap_forecasts(X_train, y_train, X_val, forecast_horizon, n_components, 
                                num_bootstraps=10, save_results=True):
    """Generate ensemble forecasts using bootstrap resampling"""
    model_dir = "pca_model_checkpoints"
    os.makedirs(model_dir, exist_ok=True)
    
    results_dir = "pca_forecast_results"
    os.makedirs(results_dir, exist_ok=True)
    
    forecasts = []
    models = []

    for i in range(num_bootstraps):
        indices = np.random.choice(len(X_train), len(X_train), replace=True)
        X_bootstrap = X_train[indices]
        y_bootstrap = y_train[indices]

        model, _ = create_train_model(X_bootstrap, y_bootstrap, forecast_horizon, n_components, model_dir, i)
        models.append(model)

        forecast = model.predict(X_val, verbose=1)
        forecasts.append(forecast)

    forecasts = np.array(forecasts)

    mean_forecast = np.mean(forecasts, axis=0)
    lower_bound = np.quantile(forecasts, 0.05, axis=0)
    upper_bound = np.quantile(forecasts, 0.95, axis=0)

    if save_results:
        results = {
            'mean_forecast': mean_forecast,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound,
            'forecasts': forecasts
        }
        
        results_path = os.path.join(results_dir, 'pca_forecast_results.pkl')
        with open(results_path, 'wb') as f:
            pickle.dump(results, f)

    return mean_forecast, lower_bound, upper_bound, models, forecasts

def load_forecast_results(results_dir="pca_forecast_results"):
    """Load saved forecast results"""
    results_path = os.path.join(results_dir, 'pca_forecast_results.pkl')
    
    if not os.path.exists(results_path):
        raise FileNotFoundError(f"Results file not found at {results_path}")
    
    with open(results_path, 'rb') as f:
        results = pickle.load(f)
    
    return results['mean_forecast'], results['lower_bound'], results['upper_bound'], results['forecasts']

def load_trained_models(num_bootstraps, model_dir="pca_model_checkpoints"):
    """Load trained models"""
    if not os.path.exists(model_dir):
        raise FileNotFoundError(f"Model directory {model_dir} not found")
    
    models = []
    for i in range(num_bootstraps):
        model_path = os.path.join(model_dir, f"pca_model_{i}.keras")
        if os.path.exists(model_path):
            model = load_model(model_path)
            models.append(model)
    
    return models

def predict_future(model, last_sequence, future_steps, forecast_horizon, pca_scaler, pca, n_components, model_id):
    """Generate future predictions using a trained model"""
    future_predictions_pc = []
    curr_sequence = last_sequence.copy()

    steps_completed = 0
    while steps_completed < future_steps:
        curr_sequence_reshaped = curr_sequence.reshape(1, curr_sequence.shape[0], curr_sequence.shape[1])
        next_preds = model.predict(curr_sequence_reshaped, verbose=0)[0]
        
        # Reshape predictions for principal components
        next_preds_reshaped = next_preds.reshape(forecast_horizon, n_components)
        
        steps_to_add = min(forecast_horizon, future_steps - steps_completed)
        future_predictions_pc.extend(next_preds_reshaped[:steps_to_add])
        
        curr_sequence = np.roll(curr_sequence, -steps_to_add, axis=0)
        
        for i in range(steps_to_add):
            curr_sequence[-steps_to_add+i] = next_preds_reshaped[i]
        
        steps_completed += steps_to_add

    future_predictions_pc = np.array(future_predictions_pc)
    
    # Inverse transform PCA scaling
    future_predictions_scaled = pca_scaler.inverse_transform(future_predictions_pc)
    
    # Inverse transform PCA
    future_predictions_original = pca.inverse_transform(future_predictions_scaled)
    
    # Extract SSN and TSI
    future_predictions_ssn = future_predictions_original[:, 0].reshape(-1, 1)
    future_predictions_tsi = future_predictions_original[:, 1].reshape(-1, 1)

    return future_predictions_ssn, future_predictions_tsi, future_predictions_pc

def generate_future_dates(last_date, num_months):
    """Generate a range of future dates"""
    future_dates = pd.date_range(start=last_date, periods=num_months+1, freq='MS')[1:]
    return future_dates

def calculate_evaluation_metrics(actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv):
    """Calculate average evaluation metrics across all forecasts"""
    rmse_values = []
    picp_values = []
    mpiw_values = []

    for i in range(len(actual_values)):
        rmse, picp, mpiw = calculate_metrics(
            actual_values[i],
            mean_forecast_inv[i],
            lower_bound_inv[i],
            upper_bound_inv[i]
        )
        rmse_values.append(rmse)
        picp_values.append(picp)
        mpiw_values.append(mpiw)

    return np.mean(rmse_values), np.mean(picp_values), np.mean(mpiw_values)

def plot_forecast(df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv, 
                 future_dates, future_mean, future_lower, future_upper,
                 cycle_24_start, cycle_25_start, forecast_horizon, target_var):
    """Plot historical data and forecasts with uncertainty intervals"""
    start_date = pd.to_datetime('1996-01-01')
    plt.figure(figsize=(15, 8))

    historical_mask = df.index >= start_date
    plt.plot(df.index[historical_mask], df[target_var][historical_mask], 'b-', label=f'Historical {target_var} Data')

    for i in range(len(mean_forecast_inv)):
        pred_dates = val_dates[i:i+forecast_horizon]
        if len(pred_dates) == len(mean_forecast_inv[i]):
            plt.plot(pred_dates, mean_forecast_inv[i], 'r-', alpha=0.5, label=f'Validation {target_var} Predictions' if i == 0 else "")
            plt.fill_between(pred_dates, lower_bound_inv[i], upper_bound_inv[i], color='r', alpha=0.2, label='90% Confidence Interval' if i == 0 else "")

    plt.plot(future_dates, future_mean, 'g-', label=f'Future {target_var} Predictions')
    plt.fill_between(future_dates, future_lower.flatten(), future_upper.flatten(), color='g', alpha=0.2, label='Future 90% Confidence Interval')
    plt.axvline(x=cycle_24_start, color='k', linestyle='--', label='Cycle 24 Start')
    plt.axvline(x=cycle_25_start, color='k', linestyle='--', label='Cycle 25 Start')
    plt.title(f'{target_var} Forecast with Uncertainty (PCA-based)')
    plt.xlabel('Date')
    plt.ylabel(f'{target_var}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'pca_{target_var.lower()}_forecast.png', dpi=300, bbox_inches='tight')
    plt.close()

def plot_principal_components(pc_data, pc_dates, future_pc_data, future_dates, n_components):
    """Plot principal components data and forecasts"""
    plt.figure(figsize=(15, 8))
    
    for i in range(n_components):
        plt.subplot(n_components, 1, i+1)
        plt.plot(pc_dates, pc_data[:, i], 'b-', label=f'Historical PC{i+1}')
        plt.plot(future_dates, future_pc_data[:, i], 'g-', label=f'Forecast PC{i+1}')
        plt.title(f'Principal Component {i+1}')
        plt.legend()
        plt.grid(True)
    
    plt.tight_layout()
    plt.savefig('principal_components.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

if __name__ == "__main__":
    TRAIN_MODELS = True
    
    # Load data
    ssn_df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv')
    tsi_df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/tsi.csv')
    
    # Merge datasets
    df = pd.merge(ssn_df, tsi_df, left_index=True, right_index=True, suffixes=('', '_tsi'))
    df = df.rename(columns={'tsi_tsi': 'tsi'})
    
    print("Data summary:")
    print(df.describe())
    print(f"Correlation between SSN and TSI: {df['ssn'].corr(df['tsi']):.4f}")
    
    # Extract features and prepare data
    features = df[['ssn', 'tsi']].values
    
    # Apply PCA
    n_components = 2  # Using 2 components to capture full variance
    pca = PCA(n_components=n_components)
    
    # Fit PCA and transform the data
    pca_features = pca.fit_transform(features)
    
    print("PCA explained variance ratio:", pca.explained_variance_ratio_)
    print("PCA components:\n", pca.components_)
    
    # Scale PCA components
    pca_scaler = MinMaxScaler(feature_range=(0, 1))
    pca_scaled = pca_scaler.fit_transform(pca_features)
    
    # Save scalers and PCA model
    with open('pca_model.pkl', 'wb') as f:
        pickle.dump(pca, f)
    with open('pca_scaler.pkl', 'wb') as f:
        pickle.dump(pca_scaler, f)
    
    # Define cycle start dates
    cycle_24_start = pd.to_datetime('2008-12-01')
    cycle_25_start = pd.to_datetime('2019-12-01')
    validation_start = pd.to_datetime('2021-01-01')
    
    # Prepare training and validation data
    train_data = pca_scaled[df.index < cycle_25_start]
    val_data = pca_scaled[(df.index >= validation_start)]
    val_dates = df.index[(df.index >= validation_start)]
    
    # Parameters for sequence creation
    forecast_horizon = 1
    seq_length = 8 * 12  # 8 years of monthly data
    
    # Create sequences for training
    X_train, y_train = create_forecast_sequences(train_data, seq_length, forecast_horizon)
    
    # Flatten y_train for model training
    y_train_flattened = y_train.reshape(y_train.shape[0], -1)
    
    # Prepare validation sequences
    X_val = []
    y_val_pc = []
    
    for i in range(len(val_dates) - forecast_horizon + 1):
        start_idx = df.index.get_loc(val_dates[i]) - seq_length
        end_idx = df.index.get_loc(val_dates[i])
        forecast_end_idx = df.index.get_loc(val_dates[i]) + forecast_horizon
        
        if start_idx >= 0:
            X_val.append(pca_scaled[start_idx:end_idx])
            y_val_pc.append(pca_scaled[end_idx:forecast_end_idx])
    
    X_val = np.array(X_val)
    y_val_pc = np.array(y_val_pc)
    
    # Train models or load existing ones
    num_bootstraps = 10
    if TRAIN_MODELS:
        mean_forecast, lower_bound, upper_bound, models, forecasts = generate_bootstrap_forecasts(
            X_train, y_train_flattened, X_val, forecast_horizon, n_components, num_bootstraps=num_bootstraps
        )
    else:
        mean_forecast, lower_bound, upper_bound, forecasts = load_forecast_results()
        models = load_trained_models(num_bootstraps)
    
    # Reshape forecasts
    mean_forecast_reshaped = mean_forecast.reshape(-1, forecast_horizon, n_components)
    lower_bound_reshaped = lower_bound.reshape(-1, forecast_horizon, n_components)
    upper_bound_reshaped = upper_bound.reshape(-1, forecast_horizon, n_components)
    
    # Transform PCA forecasts back to original space for evaluation
    mean_forecast_scaled = np.array([pca_scaler.inverse_transform(f) for f in mean_forecast_reshaped])
    lower_bound_scaled = np.array([pca_scaler.inverse_transform(f) for f in lower_bound_reshaped])
    upper_bound_scaled = np.array([pca_scaler.inverse_transform(f) for f in upper_bound_reshaped])
    
    # Inverse transform PCA
    mean_forecast_original = np.array([pca.inverse_transform(f) for f in mean_forecast_scaled])
    lower_bound_original = np.array([pca.inverse_transform(f) for f in lower_bound_scaled])
    upper_bound_original = np.array([pca.inverse_transform(f) for f in upper_bound_scaled])
    
    # Extract SSN and TSI forecasts
    ssn_mean_forecast_inv = np.array([f[:, 0] for f in mean_forecast_original])
    ssn_lower_bound_inv = np.array([f[:, 0] for f in lower_bound_original])
    ssn_upper_bound_inv = np.array([f[:, 0] for f in upper_bound_original])
    
    tsi_mean_forecast_inv = np.array([f[:, 1] for f in mean_forecast_original])
    tsi_lower_bound_inv = np.array([f[:, 1] for f in lower_bound_original])
    tsi_upper_bound_inv = np.array([f[:, 1] for f in upper_bound_original])
    
    # Get actual values for evaluation
    ssn_actual_values = []
    tsi_actual_values = []
    
    for i in range(len(y_val_pc)):
        # Inverse transform PCA scaled values
        pc_inv = pca_scaler.inverse_transform(y_val_pc[i])
        original_inv = pca.inverse_transform(pc_inv)
        
        ssn_inv = original_inv[:, 0]
        tsi_inv = original_inv[:, 1]
        
        ssn_actual_values.append(ssn_inv)
        tsi_actual_values.append(tsi_inv)
    
    ssn_actual_values = np.array(ssn_actual_values)
    tsi_actual_values = np.array(tsi_actual_values)
    
    # Calculate evaluation metrics
    ssn_avg_rmse, ssn_avg_picp, ssn_avg_mpiw = calculate_evaluation_metrics(
        ssn_actual_values, ssn_mean_forecast_inv, ssn_lower_bound_inv, ssn_upper_bound_inv
    )
    
    tsi_avg_rmse, tsi_avg_picp, tsi_avg_mpiw = calculate_evaluation_metrics(
        tsi_actual_values, tsi_mean_forecast_inv, tsi_lower_bound_inv, tsi_upper_bound_inv
    )
    
    # Print metrics
    print("\n===== SSN EVALUATION METRICS (PCA-based) =====")
    print(f"Average RMSE: {ssn_avg_rmse:.4f}")
    print(f"Average PICP: {ssn_avg_picp:.4f}")
    print(f"Average MPIW: {ssn_avg_mpiw:.4f}")
    print("==============================\n")
    
    print("\n===== TSI EVALUATION METRICS (PCA-based) =====")
    print(f"Average RMSE: {tsi_avg_rmse:.4f}")
    print(f"Average PICP: {tsi_avg_picp:.4f}")
    print(f"Average MPIW: {tsi_avg_mpiw:.4f}")
    print("==============================\n")
    
    # Generate future predictions
    last_sequence = pca_scaled[-seq_length:].reshape(seq_length, n_components)
    last_date = df.index[-1]
    future_steps = (2030 - last_date.year) * 12 + (12 - last_date.month)
    future_dates = generate_future_dates(last_date, future_steps)
    
    future_ssn_forecasts = []
    future_tsi_forecasts = []
    future_pc_forecasts = []
    
    for i, model in enumerate(models):
        future_ssn, future_tsi, future_pc = predict_future(
            model, last_sequence, future_steps, forecast_horizon, 
            pca_scaler, pca, n_components, i
        )
        future_ssn_forecasts.append(future_ssn)
        future_tsi_forecasts.append(future_tsi)
        future_pc_forecasts.append(future_pc)
    
    future_ssn_forecasts = np.array(future_ssn_forecasts)
    future_tsi_forecasts = np.array(future_tsi_forecasts)
    future_pc_forecasts = np.array(future_pc_forecasts)
    
    # Calculate statistics for future forecasts
    future_ssn_mean = np.mean(future_ssn_forecasts, axis=0)
    future_ssn_lower = np.quantile(future_ssn_forecasts, 0.05, axis=0)
    future_ssn_upper = np.quantile(future_ssn_forecasts, 0.95, axis=0)
    
    future_tsi_mean = np.mean(future_tsi_forecasts, axis=0)
    future_tsi_lower = np.quantile(future_tsi_forecasts, 0.05, axis=0)
    future_tsi_upper = np.quantile(future_tsi_forecasts, 0.95, axis=0)
    
    future_pc_mean = np.mean(future_pc_forecasts, axis=0)
    
    # Save future predictions
    future_results = {
        'future_ssn_mean': future_ssn_mean,
        'future_ssn_lower': future_ssn_lower,
        'future_ssn_upper': future_ssn_upper,
        'future_tsi_mean': future_tsi_mean,
        'future_tsi_lower': future_tsi_lower,
        'future_tsi_upper': future_tsi_upper,
        'future_pc_mean': future_pc_mean,
        'future_dates': future_dates
    }
    
    with open('pca_future_predictions.pkl', 'wb') as f:
        pickle.dump(future_results, f)
    
    # Plot results
    plot_forecast(
        df, val_dates, ssn_mean_forecast_inv, ssn_lower_bound_inv, ssn_upper_bound_inv,
        future_dates, future_ssn_mean, future_ssn_lower, future_ssn_upper,
        cycle_24_start, cycle_25_start, forecast_horizon, 'ssn'
    )
    
    plot_forecast(
        df, val_dates, tsi_mean_forecast_inv, tsi_lower_bound_inv, tsi_upper_bound_inv,
        future_dates, future_tsi_mean, future_tsi_lower, future_tsi_upper,
        cycle_24_start, cycle_25_start, forecast_horizon, 'tsi'
    )
    
    # Plot principal components
    plot_principal_components(
        pca_scaled, df.index, future_pc_mean, future_dates, n_components
    )
    
    print("PCA-based forecasting process completed successfully")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
import os
import pickle

np.random.seed(42)
tf.random.set_seed(42)

# Configure GPU if available
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

def load_data(file_path):
    """Load and prepare data from CSV files"""
    df = pd.read_csv(file_path)
    df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
    df = df.set_index('date')
    return df

def create_forecast_sequences(data, seq_length, forecast_horizon):
    """Create input-output sequences for forecasting"""
    X, y = [], []
    for i in range(len(data) - seq_length - forecast_horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length:i+seq_length+forecast_horizon])
    return np.array(X), np.array(y)

def calculate_metrics(y_true, y_pred, y_lower, y_upper):
    """Calculate evaluation metrics for forecasts"""
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    y_lower = y_lower.flatten()
    y_upper = y_upper.flatten()
    
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    within_interval = np.logical_and(y_true >= y_lower, y_true <= y_upper)
    picp = np.mean(within_interval)  # Prediction Interval Coverage Probability
    mpiw = np.mean(y_upper - y_lower)  # Mean Prediction Interval Width
    
    return rmse, picp, mpiw

def create_train_model(X_train, y_train, forecast_horizon, n_features, model_dir, bootstrap_id):
    """Create and train LSTM model"""
    os.makedirs(model_dir, exist_ok=True)
    
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], n_features)),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(forecast_horizon * n_features)  # Output forecasts for all principal components
    ])

    model.compile(optimizer='adam', loss='mse')

    checkpoint_path = os.path.join(model_dir, f"pca_model_{bootstrap_id}.keras")
    
    checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_loss',
        save_best_only=True,
        mode='min',
        save_weights_only=False,
        verbose=1
    )
    
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    return model, history

def generate_bootstrap_forecasts(X_train, y_train, X_val, forecast_horizon, n_components, 
                                num_bootstraps=10, save_results=True):
    """Generate ensemble forecasts using bootstrap resampling"""
    model_dir = "pca_model_checkpoints"
    os.makedirs(model_dir, exist_ok=True)
    
    results_dir = "pca_forecast_results"
    os.makedirs(results_dir, exist_ok=True)
    
    forecasts = []
    models = []

    for i in range(num_bootstraps):
        indices = np.random.choice(len(X_train), len(X_train), replace=True)
        X_bootstrap = X_train[indices]
        y_bootstrap = y_train[indices]

        model, _ = create_train_model(X_bootstrap, y_bootstrap, forecast_horizon, n_components, model_dir, i)
        models.append(model)

        forecast = model.predict(X_val, verbose=1)
        forecasts.append(forecast)

    forecasts = np.array(forecasts)

    mean_forecast = np.mean(forecasts, axis=0)
    lower_bound = np.quantile(forecasts, 0.05, axis=0)
    upper_bound = np.quantile(forecasts, 0.95, axis=0)

    if save_results:
        results = {
            'mean_forecast': mean_forecast,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound,
            'forecasts': forecasts
        }
        
        results_path = os.path.join(results_dir, 'pca_forecast_results.pkl')
        with open(results_path, 'wb') as f:
            pickle.dump(results, f)

    return mean_forecast, lower_bound, upper_bound, models, forecasts

def load_forecast_results(results_dir="pca_forecast_results"):
    """Load saved forecast results"""
    results_path = os.path.join(results_dir, 'pca_forecast_results.pkl')
    
    if not os.path.exists(results_path):
        raise FileNotFoundError(f"Results file not found at {results_path}")
    
    with open(results_path, 'rb') as f:
        results = pickle.load(f)
    
    return results['mean_forecast'], results['lower_bound'], results['upper_bound'], results['forecasts']

def load_trained_models(num_bootstraps, model_dir="pca_model_checkpoints"):
    """Load trained models"""
    if not os.path.exists(model_dir):
        raise FileNotFoundError(f"Model directory {model_dir} not found")
    
    models = []
    for i in range(num_bootstraps):
        model_path = os.path.join(model_dir, f"pca_model_{i}.keras")
        if os.path.exists(model_path):
            model = load_model(model_path)
            models.append(model)
    
    return models

def predict_future(model, last_sequence, future_steps, forecast_horizon, pca_scaler, pca, n_components, model_id):
    """Generate future predictions using a trained model"""
    future_predictions_pc = []
    curr_sequence = last_sequence.copy()

    steps_completed = 0
    while steps_completed < future_steps:
        curr_sequence_reshaped = curr_sequence.reshape(1, curr_sequence.shape[0], curr_sequence.shape[1])
        next_preds = model.predict(curr_sequence_reshaped, verbose=0)[0]
        
        # Reshape predictions for principal components
        next_preds_reshaped = next_preds.reshape(forecast_horizon, n_components)
        
        steps_to_add = min(forecast_horizon, future_steps - steps_completed)
        future_predictions_pc.extend(next_preds_reshaped[:steps_to_add])
        
        curr_sequence = np.roll(curr_sequence, -steps_to_add, axis=0)
        
        for i in range(steps_to_add):
            curr_sequence[-steps_to_add+i] = next_preds_reshaped[i]
        
        steps_completed += steps_to_add

    future_predictions_pc = np.array(future_predictions_pc)
    
    # Inverse transform PCA scaling
    future_predictions_scaled = pca_scaler.inverse_transform(future_predictions_pc)
    
    # Inverse transform PCA
    future_predictions_original = pca.inverse_transform(future_predictions_scaled)
    
    # Extract SSN and TSI
    future_predictions_ssn = future_predictions_original[:, 0].reshape(-1, 1)
    future_predictions_tsi = future_predictions_original[:, 1].reshape(-1, 1)

    return future_predictions_ssn, future_predictions_tsi, future_predictions_pc

def generate_future_dates(last_date, num_months):
    """Generate a range of future dates"""
    future_dates = pd.date_range(start=last_date, periods=num_months+1, freq='MS')[1:]
    return future_dates

def calculate_evaluation_metrics(actual_values, mean_forecast_inv, lower_bound_inv, upper_bound_inv):
    """Calculate average evaluation metrics across all forecasts"""
    rmse_values = []
    picp_values = []
    mpiw_values = []

    for i in range(len(actual_values)):
        rmse, picp, mpiw = calculate_metrics(
            actual_values[i],
            mean_forecast_inv[i],
            lower_bound_inv[i],
            upper_bound_inv[i]
        )
        rmse_values.append(rmse)
        picp_values.append(picp)
        mpiw_values.append(mpiw)

    return np.mean(rmse_values), np.mean(picp_values), np.mean(mpiw_values)

def plot_forecast(df, val_dates, mean_forecast_inv, lower_bound_inv, upper_bound_inv, 
                 future_dates, future_mean, future_lower, future_upper,
                 cycle_24_start, cycle_25_start, forecast_horizon, target_var):
    """Plot historical data and forecasts with uncertainty intervals"""
    start_date = pd.to_datetime('1996-01-01')
    plt.figure(figsize=(15, 8))

    historical_mask = df.index >= start_date
    plt.plot(df.index[historical_mask], df[target_var][historical_mask], 'b-', label=f'Historical {target_var} Data')

    for i in range(len(mean_forecast_inv)):
        pred_dates = val_dates[i:i+forecast_horizon]
        if len(pred_dates) == len(mean_forecast_inv[i]):
            plt.plot(pred_dates, mean_forecast_inv[i], 'r-', alpha=0.5, label=f'Validation {target_var} Predictions' if i == 0 else "")
            plt.fill_between(pred_dates, lower_bound_inv[i], upper_bound_inv[i], color='r', alpha=0.2, label='90% Confidence Interval' if i == 0 else "")

    plt.plot(future_dates, future_mean, 'g-', label=f'Future {target_var} Predictions')
    plt.fill_between(future_dates, future_lower.flatten(), future_upper.flatten(), color='g', alpha=0.2, label='Future 90% Confidence Interval')
    plt.axvline(x=cycle_24_start, color='k', linestyle='--', label='Cycle 24 Start')
    plt.axvline(x=cycle_25_start, color='k', linestyle='--', label='Cycle 25 Start')
    plt.title(f'{target_var} Forecast with Uncertainty (PCA-based)')
    plt.xlabel('Date')
    plt.ylabel(f'{target_var}')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'pca_{target_var.lower()}_forecast.png', dpi=300, bbox_inches='tight')
    plt.close()

def plot_principal_components(pc_data, pc_dates, future_pc_data, future_dates, n_components):
    """Plot principal components data and forecasts"""
    plt.figure(figsize=(15, 8))
    
    for i in range(n_components):
        plt.subplot(n_components, 1, i+1)
        plt.plot(pc_dates, pc_data[:, i], 'b-', label=f'Historical PC{i+1}')
        plt.plot(future_dates, future_pc_data[:, i], 'g-', label=f'Forecast PC{i+1}')
        plt.title(f'Principal Component {i+1}')
        plt.legend()
        plt.grid(True)
    
    plt.tight_layout()
    plt.savefig('principal_components.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

if __name__ == "__main__":
    TRAIN_MODELS = True
    
    # Load data
    ssn_df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/sunspot.csv')
    tsi_df = load_data('/Users/suryatejachalla/Projects/Solar-Data-Analysis/Data/processed/tsi.csv')
    
    # Merge datasets
    df = pd.merge(ssn_df, tsi_df, left_index=True, right_index=True, suffixes=('', '_tsi'))
    df = df.rename(columns={'tsi_tsi': 'tsi'})
    
    print("Data summary:")
    print(df.describe())
    print(f"Correlation between SSN and TSI: {df['ssn'].corr(df['tsi']):.4f}")
    
    # Extract features and prepare data
    features = df[['ssn', 'tsi']].values
    
    # Apply PCA
    n_components = 2  # Using 2 components to capture full variance
    pca = PCA(n_components=n_components)
    
    # Fit PCA and transform the data
    pca_features = pca.fit_transform(features)
    
    print("PCA explained variance ratio:", pca.explained_variance_ratio_)
    print("PCA components:\n", pca.components_)
    
    # Scale PCA components
    pca_scaler = MinMaxScaler(feature_range=(0, 1))
    pca_scaled = pca_scaler.fit_transform(pca_features)
    
    # Save scalers and PCA model
    with open('pca_model.pkl', 'wb') as f:
        pickle.dump(pca, f)
    with open('pca_scaler.pkl', 'wb') as f:
        pickle.dump(pca_scaler, f)
    
    # Define cycle start dates
    cycle_24_start = pd.to_datetime('2008-12-01')
    cycle_25_start = pd.to_datetime('2019-12-01')
    validation_start = pd.to_datetime('2021-01-01')
    
    # Prepare training and validation data
    train_data = pca_scaled[df.index < cycle_25_start]
    val_data = pca_scaled[(df.index >= validation_start)]
    val_dates = df.index[(df.index >= validation_start)]
    
    # Parameters for sequence creation
    forecast_horizon = 1
    seq_length = 8 * 12  # 8 years of monthly data
    
    # Create sequences for training
    X_train, y_train = create_forecast_sequences(train_data, seq_length, forecast_horizon)
    
    # Flatten y_train for model training
    y_train_flattened = y_train.reshape(y_train.shape[0], -1)
    
    # Prepare validation sequences
    X_val = []
    y_val_pc = []
    
    for i in range(len(val_dates) - forecast_horizon + 1):
        start_idx = df.index.get_loc(val_dates[i]) - seq_length
        end_idx = df.index.get_loc(val_dates[i])
        forecast_end_idx = df.index.get_loc(val_dates[i]) + forecast_horizon
        
        if start_idx >= 0:
            X_val.append(pca_scaled[start_idx:end_idx])
            y_val_pc.append(pca_scaled[end_idx:forecast_end_idx])
    
    X_val = np.array(X_val)
    y_val_pc = np.array(y_val_pc)
    
    # Train models or load existing ones
    num_bootstraps = 10
    if TRAIN_MODELS:
        mean_forecast, lower_bound, upper_bound, models, forecasts = generate_bootstrap_forecasts(
            X_train, y_train_flattened, X_val, forecast_horizon, n_components, num_bootstraps=num_bootstraps
        )
    else:
        mean_forecast, lower_bound, upper_bound, forecasts = load_forecast_results()
        models = load_trained_models(num_bootstraps)
    
    # Reshape forecasts
    mean_forecast_reshaped = mean_forecast.reshape(-1, forecast_horizon, n_components)
    lower_bound_reshaped = lower_bound.reshape(-1, forecast_horizon, n_components)
    upper_bound_reshaped = upper_bound.reshape(-1, forecast_horizon, n_components)
    
    # Transform PCA forecasts back to original space for evaluation
    mean_forecast_scaled = np.array([pca_scaler.inverse_transform(f) for f in mean_forecast_reshaped])
    lower_bound_scaled = np.array([pca_scaler.inverse_transform(f) for f in lower_bound_reshaped])
    upper_bound_scaled = np.array([pca_scaler.inverse_transform(f) for f in upper_bound_reshaped])
    
    # Inverse transform PCA
    mean_forecast_original = np.array([pca.inverse_transform(f) for f in mean_forecast_scaled])
    lower_bound_original = np.array([pca.inverse_transform(f) for f in lower_bound_scaled])
    upper_bound_original = np.array([pca.inverse_transform(f) for f in upper_bound_scaled])
    
    # Extract SSN and TSI forecasts
    ssn_mean_forecast_inv = np.array([f[:, 0] for f in mean_forecast_original])
    ssn_lower_bound_inv = np.array([f[:, 0] for f in lower_bound_original])
    ssn_upper_bound_inv = np.array([f[:, 0] for f in upper_bound_original])
    
    tsi_mean_forecast_inv = np.array([f[:, 1] for f in mean_forecast_original])
    tsi_lower_bound_inv = np.array([f[:, 1] for f in lower_bound_original])
    tsi_upper_bound_inv = np.array([f[:, 1] for f in upper_bound_original])
    
    # Get actual values for evaluation
    ssn_actual_values = []
    tsi_actual_values = []
    
    for i in range(len(y_val_pc)):
        # Inverse transform PCA scaled values
        pc_inv = pca_scaler.inverse_transform(y_val_pc[i])
        original_inv = pca.inverse_transform(pc_inv)
        
        ssn_inv = original_inv[:, 0]
        tsi_inv = original_inv[:, 1]
        
        ssn_actual_values.append(ssn_inv)
        tsi_actual_values.append(tsi_inv)
    
    ssn_actual_values = np.array(ssn_actual_values)
    tsi_actual_values = np.array(tsi_actual_values)
    
    # Calculate evaluation metrics
    ssn_avg_rmse, ssn_avg_picp, ssn_avg_mpiw = calculate_evaluation_metrics(
        ssn_actual_values, ssn_mean_forecast_inv, ssn_lower_bound_inv, ssn_upper_bound_inv
    )
    
    tsi_avg_rmse, tsi_avg_picp, tsi_avg_mpiw = calculate_evaluation_metrics(
        tsi_actual_values, tsi_mean_forecast_inv, tsi_lower_bound_inv, tsi_upper_bound_inv
    )
    
    # Print metrics
    print("\n===== SSN EVALUATION METRICS (PCA-based) =====")
    print(f"Average RMSE: {ssn_avg_rmse:.4f}")
    print(f"Average PICP: {ssn_avg_picp:.4f}")
    print(f"Average MPIW: {ssn_avg_mpiw:.4f}")
    print("==============================\n")
    
    print("\n===== TSI EVALUATION METRICS (PCA-based) =====")
    print(f"Average RMSE: {tsi_avg_rmse:.4f}")
    print(f"Average PICP: {tsi_avg_picp:.4f}")
    print(f"Average MPIW: {tsi_avg_mpiw:.4f}")
    print("==============================\n")
    
    # Generate future predictions
    last_sequence = pca_scaled[-seq_length:].reshape(seq_length, n_components)
    last_date = df.index[-1]
    future_steps = (2030 - last_date.year) * 12 + (12 - last_date.month)
    future_dates = generate_future_dates(last_date, future_steps)
    
    future_ssn_forecasts = []
    future_tsi_forecasts = []
    future_pc_forecasts = []
    
    for i, model in enumerate(models):
        future_ssn, future_tsi, future_pc = predict_future(
            model, last_sequence, future_steps, forecast_horizon, 
            pca_scaler, pca, n_components, i
        )
        future_ssn_forecasts.append(future_ssn)
        future_tsi_forecasts.append(future_tsi)
        future_pc_forecasts.append(future_pc)
    
    future_ssn_forecasts = np.array(future_ssn_forecasts)
    future_tsi_forecasts = np.array(future_tsi_forecasts)
    future_pc_forecasts = np.array(future_pc_forecasts)
    
    # Calculate statistics for future forecasts
    future_ssn_mean = np.mean(future_ssn_forecasts, axis=0)
    future_ssn_lower = np.quantile(future_ssn_forecasts, 0.05, axis=0)
    future_ssn_upper = np.quantile(future_ssn_forecasts, 0.95, axis=0)
    
    future_tsi_mean = np.mean(future_tsi_forecasts, axis=0)
    future_tsi_lower = np.quantile(future_tsi_forecasts, 0.05, axis=0)
    future_tsi_upper = np.quantile(future_tsi_forecasts, 0.95, axis=0)
    
    future_pc_mean = np.mean(future_pc_forecasts, axis=0)
    
    # Save future predictions
    future_results = {
        'future_ssn_mean': future_ssn_mean,
        'future_ssn_lower': future_ssn_lower,
        'future_ssn_upper': future_ssn_upper,
        'future_tsi_mean': future_tsi_mean,
        'future_tsi_lower': future_tsi_lower,
        'future_tsi_upper': future_tsi_upper,
        'future_pc_mean': future_pc_mean,
        'future_dates': future_dates
    }
    
    with open('pca_future_predictions.pkl', 'wb') as f:
        pickle.dump(future_results, f)
    
    # Plot results
    plot_forecast(
        df, val_dates, ssn_mean_forecast_inv, ssn_lower_bound_inv, ssn_upper_bound_inv,
        future_dates, future_ssn_mean, future_ssn_lower, future_ssn_upper,
        cycle_24_start, cycle_25_start, forecast_horizon, 'ssn'
    )
    
    plot_forecast(
        df, val_dates, tsi_mean_forecast_inv, tsi_lower_bound_inv, tsi_upper_bound_inv,
        future_dates, future_tsi_mean, future_tsi_lower, future_tsi_upper,
        cycle_24_start, cycle_25_start, forecast_horizon, 'tsi'
    )
    
    # Plot principal components
    plot_principal_components(
        pca_scaled, df.index, future_pc_mean, future_dates, n_components
    )
    
    print("PCA-based forecasting process completed successfully")
# Out:
# Data summary:
#               ssn         year       month     year_tsi   month_tsi  \
# count  924.000000   924.000000  924.000000   924.000000  924.000000
# mean    93.807468  1985.583333    6.500000  1985.583333    6.500000
# std     71.508209    22.243618    3.453922    22.243618    3.453922
# min      1.800000  1947.000000    1.000000  1947.000000    1.000000
# 25%     28.325000  1966.000000    3.750000  1966.000000    3.750000
# 50%     84.050000  1986.000000    6.500000  1986.000000    6.500000
# 75%    149.950000  2005.000000    9.250000  2005.000000    9.250000
# max    285.000000  2024.000000   12.000000  2024.000000   12.000000
#
#                tsi
# count   924.000000
# mean   1363.423637
# std       0.354047
# min    1362.889401
# 25%    1363.075220
# 50%    1363.427315
# 75%    1363.741120
# max    1364.138153
# Correlation between SSN and TSI: 0.9065
# PCA explained variance ratio: [9.99995630e-01 4.37041416e-06]
# PCA components:
#  [[ 0.99998993  0.00448809]
#  [-0.00448809  0.99998993]]
# 2025-03-20 17:04:12.241041: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-03-20 17:04:12.241069: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-03-20 17:04:12.241075: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-03-20 17:04:12.241089: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-20 17:04:12.241099: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/envs/ssn/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 2025-03-20 17:04:12.800433: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1304
# Epoch 1: val_loss improved from inf to 0.01648, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.1276 - val_loss: 0.0165
# Epoch 2/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0180
# Epoch 2: val_loss improved from 0.01648 to 0.00778, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0178 - val_loss: 0.0078
# Epoch 3/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0134
# Epoch 3: val_loss improved from 0.00778 to 0.00648, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0133 - val_loss: 0.0065
# Epoch 4/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0117
# Epoch 4: val_loss improved from 0.00648 to 0.00565, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0117 - val_loss: 0.0056
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0105
# Epoch 5: val_loss improved from 0.00565 to 0.00454, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0105 - val_loss: 0.0045
# Epoch 6/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0094
# Epoch 6: val_loss improved from 0.00454 to 0.00360, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0094 - val_loss: 0.0036
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0083
# Epoch 7: val_loss did not improve from 0.00360
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0083 - val_loss: 0.0036
# Epoch 8/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073
# Epoch 8: val_loss improved from 0.00360 to 0.00307, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0073 - val_loss: 0.0031
# Epoch 9/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0067
# Epoch 9: val_loss did not improve from 0.00307
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0067 - val_loss: 0.0033
# Epoch 10/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0067
# Epoch 10: val_loss improved from 0.00307 to 0.00280, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0067 - val_loss: 0.0028
# Epoch 11/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0063
# Epoch 11: val_loss improved from 0.00280 to 0.00257, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0062 - val_loss: 0.0026
# Epoch 12/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0061
# Epoch 12: val_loss did not improve from 0.00257
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0061 - val_loss: 0.0027
# Epoch 13/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0066
# Epoch 13: val_loss did not improve from 0.00257
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0060
# Epoch 14: val_loss did not improve from 0.00257
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0060 - val_loss: 0.0030
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0059
# Epoch 15: val_loss improved from 0.00257 to 0.00226, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 16/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053
# Epoch 16: val_loss did not improve from 0.00226
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 17/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0060
# Epoch 17: val_loss improved from 0.00226 to 0.00216, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0060 - val_loss: 0.0022
# Epoch 18/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0054
# Epoch 18: val_loss did not improve from 0.00216
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - val_loss: 0.0022
# Epoch 19/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055
# Epoch 19: val_loss improved from 0.00216 to 0.00194, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 20/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0056
# Epoch 20: val_loss did not improve from 0.00194
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0056 - val_loss: 0.0021
# Epoch 21/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0050
# Epoch 21: val_loss did not improve from 0.00194
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0050 - val_loss: 0.0023
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051
# Epoch 22: val_loss improved from 0.00194 to 0.00181, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044
# Epoch 23: val_loss did not improve from 0.00181
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 24/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044
# Epoch 24: val_loss did not improve from 0.00181
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 25/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048
# Epoch 25: val_loss improved from 0.00181 to 0.00154, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051
# Epoch 26: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0047
# Epoch 27: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 28/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0047
# Epoch 28: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 29/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042
# Epoch 29: val_loss improved from 0.00154 to 0.00143, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 30/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043
# Epoch 30: val_loss improved from 0.00143 to 0.00142, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042
# Epoch 31: val_loss did not improve from 0.00142
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 32: val_loss did not improve from 0.00142
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 33: val_loss did not improve from 0.00142
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 34/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043
# Epoch 34: val_loss did not improve from 0.00142
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 35/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046
# Epoch 35: val_loss did not improve from 0.00142
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0046 - val_loss: 0.0019
# Epoch 36/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 36: val_loss improved from 0.00142 to 0.00125, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044
# Epoch 37: val_loss did not improve from 0.00125
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 38/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0038
# Epoch 38: val_loss improved from 0.00125 to 0.00125, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 39/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034
# Epoch 39: val_loss did not improve from 0.00125
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 40/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039
# Epoch 40: val_loss improved from 0.00125 to 0.00117, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 41/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040
# Epoch 41: val_loss did not improve from 0.00117
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 42/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0040
# Epoch 42: val_loss did not improve from 0.00117
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 43/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 43: val_loss did not improve from 0.00117
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033
# Epoch 44: val_loss did not improve from 0.00117
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 45: val_loss improved from 0.00117 to 0.00110, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 46/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036
# Epoch 46: val_loss improved from 0.00110 to 0.00106, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 47/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034
# Epoch 47: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 48/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 48: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034
# Epoch 49: val_loss improved from 0.00106 to 0.00106, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 50/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033
# Epoch 50: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 51/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 51: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034
# Epoch 52: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 53/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033
# Epoch 53: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0037
# Epoch 54: val_loss improved from 0.00106 to 0.00093, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 9.3115e-04
# Epoch 55/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 55: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - val_loss: 9.6783e-04
# Epoch 56/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033
# Epoch 56: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 57/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033
# Epoch 57: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 58/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040
# Epoch 58: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 9.3551e-04
# Epoch 59/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032
# Epoch 59: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 60/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032
# Epoch 60: val_loss improved from 0.00093 to 0.00088, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - val_loss: 8.8238e-04
# Epoch 61/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 61: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - val_loss: 9.6209e-04
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033
# Epoch 62: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 9.0027e-04
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032
# Epoch 63: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 64: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 65/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033
# Epoch 65: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 9.4646e-04
# Epoch 66/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030
# Epoch 66: val_loss improved from 0.00088 to 0.00082, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0030 - val_loss: 8.1618e-04
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029
# Epoch 67: val_loss improved from 0.00082 to 0.00078, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - val_loss: 7.8452e-04
# Epoch 68/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025
# Epoch 68: val_loss did not improve from 0.00078
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 69: val_loss did not improve from 0.00078
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - val_loss: 9.8865e-04
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030
# Epoch 70: val_loss improved from 0.00078 to 0.00075, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - val_loss: 7.4587e-04
# Epoch 71/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 71: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024 - val_loss: 9.6024e-04
# Epoch 72/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028
# Epoch 72: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 8.3518e-04
# Epoch 73/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 73: val_loss improved from 0.00075 to 0.00072, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - val_loss: 7.1506e-04
# Epoch 74/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 74: val_loss improved from 0.00072 to 0.00067, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024 - val_loss: 6.7061e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 75: val_loss improved from 0.00067 to 0.00066, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - val_loss: 6.5559e-04
# Epoch 76/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 76: val_loss improved from 0.00066 to 0.00065, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 6.4817e-04
# Epoch 77/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 77: val_loss did not improve from 0.00065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0025 - val_loss: 6.8479e-04
# Epoch 78/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 78: val_loss did not improve from 0.00065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 7.4794e-04
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027
# Epoch 79: val_loss did not improve from 0.00065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - val_loss: 7.8224e-04
# Epoch 80/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026
# Epoch 80: val_loss improved from 0.00065 to 0.00059, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - val_loss: 5.8576e-04
# Epoch 81/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022
# Epoch 81: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0022 - val_loss: 6.7844e-04
# Epoch 82/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 82: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0024 - val_loss: 6.4486e-04
# Epoch 83/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 83: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 7.0409e-04
# Epoch 84/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025
# Epoch 84: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 9.9095e-04
# Epoch 85/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027
# Epoch 85: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - val_loss: 6.6827e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 86: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 5.8819e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 87: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 7.3454e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024
# Epoch 88: val_loss improved from 0.00059 to 0.00056, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024 - val_loss: 5.6221e-04
# Epoch 89/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021
# Epoch 89: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021 - val_loss: 5.6500e-04
# Epoch 90/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021
# Epoch 90: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021 - val_loss: 9.0566e-04
# Epoch 91/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022
# Epoch 91: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022 - val_loss: 6.1220e-04
# Epoch 92/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022
# Epoch 92: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0022 - val_loss: 7.0506e-04
# Epoch 93/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023
# Epoch 93: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0023 - val_loss: 6.1873e-04
# Epoch 94/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 94: val_loss did not improve from 0.00056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - val_loss: 8.1971e-04
# Epoch 95/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 95: val_loss improved from 0.00056 to 0.00053, saving model to pca_model_checkpoints/pca_model_0.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - val_loss: 5.2993e-04
# Epoch 96/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022
# Epoch 96: val_loss did not improve from 0.00053
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - val_loss: 6.3464e-04
# Epoch 97/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 97: val_loss did not improve from 0.00053
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 6.0230e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021
# Epoch 98: val_loss did not improve from 0.00053
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0021 - val_loss: 9.1671e-04
# Epoch 99/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 99: val_loss did not improve from 0.00053
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 7.1161e-04
# Epoch 100/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019
# Epoch 100: val_loss did not improve from 0.00053
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019 - val_loss: 6.0863e-04
# Restoring model weights from the end of the best epoch: 95.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1115
# Epoch 1: val_loss improved from inf to 0.02084, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1093 - val_loss: 0.0208
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0201
# Epoch 2: val_loss improved from 0.02084 to 0.00941, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0199 - val_loss: 0.0094
# Epoch 3/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0138
# Epoch 3: val_loss improved from 0.00941 to 0.00680, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0137 - val_loss: 0.0068
# Epoch 4/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0108
# Epoch 4: val_loss improved from 0.00680 to 0.00441, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0108 - val_loss: 0.0044
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0097
# Epoch 5: val_loss improved from 0.00441 to 0.00356, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0096 - val_loss: 0.0036
# Epoch 6/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0093
# Epoch 6: val_loss improved from 0.00356 to 0.00347, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0093 - val_loss: 0.0035
# Epoch 7/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0082
# Epoch 7: val_loss did not improve from 0.00347
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0082 - val_loss: 0.0044
# Epoch 8/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0079
# Epoch 8: val_loss improved from 0.00347 to 0.00277, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0079 - val_loss: 0.0028
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0082
# Epoch 9: val_loss improved from 0.00277 to 0.00267, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0081 - val_loss: 0.0027
# Epoch 10/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0075
# Epoch 10: val_loss did not improve from 0.00267
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 11/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0080
# Epoch 11: val_loss did not improve from 0.00267
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 12/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065
# Epoch 12: val_loss did not improve from 0.00267
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 13/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0062
# Epoch 13: val_loss improved from 0.00267 to 0.00258, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0063 - val_loss: 0.0026
# Epoch 14/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0063
# Epoch 14: val_loss improved from 0.00258 to 0.00242, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0063 - val_loss: 0.0024
# Epoch 15/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0063
# Epoch 15: val_loss improved from 0.00242 to 0.00201, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0061
# Epoch 16: val_loss did not improve from 0.00201
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 17/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0061
# Epoch 17: val_loss did not improve from 0.00201
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0060 - val_loss: 0.0024
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0056
# Epoch 18: val_loss improved from 0.00201 to 0.00179, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 19/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0054
# Epoch 19: val_loss did not improve from 0.00179
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - val_loss: 0.0019
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0054
# Epoch 20: val_loss did not improve from 0.00179
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0053 - val_loss: 0.0018
# Epoch 21/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0055
# Epoch 21: val_loss improved from 0.00179 to 0.00162, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 22/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0051
# Epoch 22: val_loss did not improve from 0.00162
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 23/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049
# Epoch 23: val_loss did not improve from 0.00162
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 24/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0047
# Epoch 24: val_loss improved from 0.00162 to 0.00154, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0045
# Epoch 25: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 26/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055
# Epoch 26: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 27/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0044
# Epoch 27: val_loss improved from 0.00154 to 0.00136, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 28/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0040
# Epoch 28: val_loss did not improve from 0.00136
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0044
# Epoch 29: val_loss did not improve from 0.00136
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042
# Epoch 30: val_loss improved from 0.00136 to 0.00133, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 31/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0043
# Epoch 31: val_loss did not improve from 0.00133
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 32/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041
# Epoch 32: val_loss did not improve from 0.00133
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 33/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0042
# Epoch 33: val_loss improved from 0.00133 to 0.00132, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 34/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 34: val_loss did not improve from 0.00132
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 35/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042
# Epoch 35: val_loss did not improve from 0.00132
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 36/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 36: val_loss did not improve from 0.00132
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 37/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 37: val_loss improved from 0.00132 to 0.00121, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0041
# Epoch 38: val_loss did not improve from 0.00121
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 39/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 39: val_loss did not improve from 0.00121
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039
# Epoch 40: val_loss improved from 0.00121 to 0.00119, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 41/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0036
# Epoch 41: val_loss did not improve from 0.00119
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 42/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0038
# Epoch 42: val_loss did not improve from 0.00119
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 43/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 43: val_loss improved from 0.00119 to 0.00119, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0034
# Epoch 44: val_loss improved from 0.00119 to 0.00107, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 45/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034
# Epoch 45: val_loss did not improve from 0.00107
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033
# Epoch 46: val_loss did not improve from 0.00107
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 47/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032
# Epoch 47: val_loss did not improve from 0.00107
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 48/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036
# Epoch 48: val_loss improved from 0.00107 to 0.00106, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 49/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031
# Epoch 49: val_loss did not improve from 0.00106
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 50: val_loss improved from 0.00106 to 0.00093, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0035 - val_loss: 9.2503e-04
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035
# Epoch 51: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 52/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 52: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032
# Epoch 53: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 54/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033
# Epoch 54: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 55/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 55: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031
# Epoch 56: val_loss did not improve from 0.00093
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 57/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032
# Epoch 57: val_loss improved from 0.00093 to 0.00088, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0032 - val_loss: 8.7636e-04
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030
# Epoch 58: val_loss did not improve from 0.00088
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 59/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031
# Epoch 59: val_loss improved from 0.00088 to 0.00087, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 8.6847e-04
# Epoch 60/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 60: val_loss did not improve from 0.00087
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 9.2933e-04
# Epoch 61/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 61: val_loss improved from 0.00087 to 0.00075, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - val_loss: 7.5361e-04
# Epoch 62/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030
# Epoch 62: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - val_loss: 8.5662e-04
# Epoch 63/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026
# Epoch 63: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0026 - val_loss: 9.8536e-04
# Epoch 64/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029
# Epoch 64: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 8.1572e-04
# Epoch 65/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 65: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 0.0010
# Epoch 66/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 66: val_loss did not improve from 0.00075
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 9.3478e-04
# Epoch 67/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028
# Epoch 67: val_loss improved from 0.00075 to 0.00067, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - val_loss: 6.7173e-04
# Epoch 68/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0025
# Epoch 68: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0025 - val_loss: 9.2628e-04
# Epoch 69/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029
# Epoch 69: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - val_loss: 8.3061e-04
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024
# Epoch 70: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024 - val_loss: 9.0345e-04
# Epoch 71/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023
# Epoch 71: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0024 - val_loss: 9.7612e-04
# Epoch 72/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023
# Epoch 72: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0023 - val_loss: 8.7951e-04
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 73: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - val_loss: 7.6996e-04
# Epoch 74/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025
# Epoch 74: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - val_loss: 8.5972e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0024
# Epoch 75: val_loss improved from 0.00067 to 0.00059, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 5.9264e-04
# Epoch 76/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0023
# Epoch 76: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0023 - val_loss: 7.2692e-04
# Epoch 77/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025
# Epoch 77: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025 - val_loss: 6.0451e-04
# Epoch 78/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 78: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 6.1120e-04
# Epoch 79/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025
# Epoch 79: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - val_loss: 6.3217e-04
# Epoch 80/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 80: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020 - val_loss: 7.2314e-04
# Epoch 81/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022
# Epoch 81: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - val_loss: 8.3666e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023
# Epoch 82: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - val_loss: 6.4241e-04
# Epoch 83/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0022
# Epoch 83: val_loss improved from 0.00059 to 0.00057, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022 - val_loss: 5.7016e-04
# Epoch 84/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019
# Epoch 84: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020 - val_loss: 5.8585e-04
# Epoch 85/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021
# Epoch 85: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021 - val_loss: 7.2140e-04
# Epoch 86/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 86: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0020 - val_loss: 7.5715e-04
# Epoch 87/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022
# Epoch 87: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - val_loss: 7.8662e-04
# Epoch 88/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 88: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020 - val_loss: 6.4389e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0020
# Epoch 89: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 6.9585e-04
# Epoch 90/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020
# Epoch 90: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 6.1396e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022
# Epoch 91: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - val_loss: 5.9410e-04
# Epoch 92/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 92: val_loss did not improve from 0.00057
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - val_loss: 6.0636e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020
# Epoch 93: val_loss improved from 0.00057 to 0.00052, saving model to pca_model_checkpoints/pca_model_1.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020 - val_loss: 5.2035e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018
# Epoch 94: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 5.4678e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 95: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019 - val_loss: 6.3196e-04
# Epoch 96/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019
# Epoch 96: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019 - val_loss: 5.8347e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 97: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - val_loss: 8.0876e-04
# Epoch 98/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018
# Epoch 98: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - val_loss: 5.3449e-04
# Epoch 99/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018
# Epoch 99: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018 - val_loss: 5.3836e-04
# Epoch 100/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018
# Epoch 100: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 6.7698e-04
# Restoring model weights from the end of the best epoch: 93.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1338
# Epoch 1: val_loss improved from inf to 0.01773, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1310 - val_loss: 0.0177
# Epoch 2/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0199
# Epoch 2: val_loss improved from 0.01773 to 0.00826, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0196 - val_loss: 0.0083
# Epoch 3/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0141
# Epoch 3: val_loss improved from 0.00826 to 0.00645, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0139 - val_loss: 0.0064
# Epoch 4/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0134
# Epoch 4: val_loss improved from 0.00645 to 0.00523, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0132 - val_loss: 0.0052
# Epoch 5/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0113
# Epoch 5: val_loss improved from 0.00523 to 0.00453, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0113 - val_loss: 0.0045
# Epoch 6/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0090
# Epoch 6: val_loss improved from 0.00453 to 0.00356, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0089 - val_loss: 0.0036
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0086
# Epoch 7: val_loss improved from 0.00356 to 0.00312, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0086 - val_loss: 0.0031
# Epoch 8/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0083
# Epoch 8: val_loss improved from 0.00312 to 0.00276, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0083 - val_loss: 0.0028
# Epoch 9/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071
# Epoch 9: val_loss improved from 0.00276 to 0.00252, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0071 - val_loss: 0.0025
# Epoch 10/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0069
# Epoch 10: val_loss did not improve from 0.00252
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0070 - val_loss: 0.0027
# Epoch 11/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0065
# Epoch 11: val_loss improved from 0.00252 to 0.00217, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0065 - val_loss: 0.0022
# Epoch 12/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065
# Epoch 12: val_loss did not improve from 0.00217
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0066 - val_loss: 0.0027
# Epoch 13/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0064
# Epoch 13: val_loss improved from 0.00217 to 0.00193, saving model to pca_model_checkpoints/pca_model_2.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0065 - val_loss: 0.0019
# Epoch 14/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0063
# Epoch 14: val_loss improved from 0.00193 to 0.00191, saving model to pca_model_checkpoints/pca_model_2.keras
# ...
# Epoch 21: val_loss improved from 0.00194 to 0.00162, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 22/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0045
# Epoch 22: val_loss did not improve from 0.00162
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 23/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0052
# Epoch 23: val_loss improved from 0.00162 to 0.00154, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 24/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0046
# Epoch 24: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0046 - val_loss: 0.0020
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0051
# Epoch 25: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 26/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044
# Epoch 26: val_loss did not improve from 0.00154
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 27/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 27: val_loss improved from 0.00154 to 0.00145, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0049
# Epoch 28: val_loss did not improve from 0.00145
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 29/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0048
# Epoch 29: val_loss did not improve from 0.00145
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 30/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042
# Epoch 30: val_loss did not improve from 0.00145
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 31/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 31: val_loss did not improve from 0.00145
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0041
# Epoch 32: val_loss improved from 0.00145 to 0.00129, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 33/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0045
# Epoch 33: val_loss did not improve from 0.00129
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 34/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 34: val_loss did not improve from 0.00129
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 35/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 35: val_loss improved from 0.00129 to 0.00123, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 36/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040
# Epoch 36: val_loss did not improve from 0.00123
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 37/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037
# Epoch 37: val_loss did not improve from 0.00123
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 38/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0040
# Epoch 38: val_loss improved from 0.00123 to 0.00113, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 39: val_loss did not improve from 0.00113
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 40/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035
# Epoch 40: val_loss improved from 0.00113 to 0.00110, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 41/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036
# Epoch 41: val_loss did not improve from 0.00110
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 42/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0043
# Epoch 42: val_loss improved from 0.00110 to 0.00110, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 43/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0035
# Epoch 43: val_loss did not improve from 0.00110
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 44/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0032
# Epoch 44: val_loss did not improve from 0.00110
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 45/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0038
# Epoch 45: val_loss did not improve from 0.00110
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037
# Epoch 46: val_loss improved from 0.00110 to 0.00106, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 47/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035
# Epoch 47: val_loss improved from 0.00106 to 0.00097, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035 - val_loss: 9.6816e-04
# Epoch 48/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033
# Epoch 48: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 49/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0035
# Epoch 49: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0035 - val_loss: 9.7244e-04
# Epoch 50/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031
# Epoch 50: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 51/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 51: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 52/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0034
# Epoch 52: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030
# Epoch 53: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - val_loss: 9.7442e-04
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035
# Epoch 54: val_loss did not improve from 0.00097
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 55/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 55: val_loss improved from 0.00097 to 0.00083, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 8.2717e-04
# Epoch 56/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030
# Epoch 56: val_loss did not improve from 0.00083
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - val_loss: 8.9142e-04
# Epoch 57/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028
# Epoch 57: val_loss did not improve from 0.00083
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - val_loss: 9.9780e-04
# Epoch 58/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032
# Epoch 58: val_loss improved from 0.00083 to 0.00080, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032 - val_loss: 7.9554e-04
# Epoch 59/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029
# Epoch 59: val_loss did not improve from 0.00080
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - val_loss: 7.9677e-04
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 60: val_loss did not improve from 0.00080
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 61/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028
# Epoch 61: val_loss improved from 0.00080 to 0.00076, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - val_loss: 7.6376e-04
# Epoch 62/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028
# Epoch 62: val_loss did not improve from 0.00076
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 63/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030
# Epoch 63: val_loss did not improve from 0.00076
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - val_loss: 8.1788e-04
# Epoch 64/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028
# Epoch 64: val_loss did not improve from 0.00076
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - val_loss: 8.4681e-04
# Epoch 65/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027
# Epoch 65: val_loss did not improve from 0.00076
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - val_loss: 7.7797e-04
# Epoch 66/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028
# Epoch 66: val_loss did not improve from 0.00076
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - val_loss: 8.5655e-04
# Epoch 67/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027
# Epoch 67: val_loss improved from 0.00076 to 0.00072, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027 - val_loss: 7.1709e-04
# Epoch 68/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027
# Epoch 68: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 8.7216e-04
# Epoch 69/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029
# Epoch 69: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - val_loss: 9.5105e-04
# Epoch 70/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027
# Epoch 70: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027 - val_loss: 8.2448e-04
# Epoch 71/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024
# Epoch 71: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024 - val_loss: 9.4163e-04
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026
# Epoch 72: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - val_loss: 7.5409e-04
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026
# Epoch 73: val_loss did not improve from 0.00072
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - val_loss: 9.2376e-04
# Epoch 74/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 74: val_loss improved from 0.00072 to 0.00069, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - val_loss: 6.9105e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024
# Epoch 75: val_loss did not improve from 0.00069
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 7.2213e-04
# Epoch 76/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 76: val_loss did not improve from 0.00069
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0024 - val_loss: 7.1343e-04
# Epoch 77/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022
# Epoch 77: val_loss improved from 0.00069 to 0.00067, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022 - val_loss: 6.7369e-04
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023
# Epoch 78: val_loss did not improve from 0.00067
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 79/100
# 17/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026
# Epoch 79: val_loss improved from 0.00067 to 0.00066, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026 - val_loss: 6.5821e-04
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0026
# Epoch 80: val_loss did not improve from 0.00066
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0026 - val_loss: 6.9740e-04
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 81: val_loss did not improve from 0.00066
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - val_loss: 7.6707e-04
# Epoch 82/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021
# Epoch 82: val_loss did not improve from 0.00066
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021 - val_loss: 7.2923e-04
# Epoch 83/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024
# Epoch 83: val_loss improved from 0.00066 to 0.00059, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 5.9041e-04
# Epoch 84/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0025
# Epoch 84: val_loss did not improve from 0.00059
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025 - val_loss: 6.4287e-04
# Epoch 85/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0024
# Epoch 85: val_loss improved from 0.00059 to 0.00052, saving model to pca_model_checkpoints/pca_model_9.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 5.2232e-04
# Epoch 86/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020
# Epoch 86: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020 - val_loss: 7.2326e-04
# Epoch 87/100
# 18/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020
# Epoch 87: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021 - val_loss: 6.5323e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019
# Epoch 88: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0019 - val_loss: 5.5422e-04
# Epoch 89/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019
# Epoch 89: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019 - val_loss: 7.1729e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0021
# Epoch 90: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - val_loss: 6.8286e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023
# Epoch 91: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - val_loss: 8.6269e-04
# Epoch 92/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021
# Epoch 92: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - val_loss: 6.6776e-04
# Epoch 93/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018
# Epoch 93: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 6.0873e-04
# Epoch 94/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021
# Epoch 94: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - val_loss: 6.1467e-04
# Epoch 95/100
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018
# Epoch 95: val_loss did not improve from 0.00052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - val_loss: 5.9715e-04
# Epoch 95: early stopping
# Restoring model weights from the end of the best epoch: 85.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
#
# ===== SSN EVALUATION METRICS (PCA-based) =====
# Average RMSE: 3.6357
# Average PICP: 0.6977
# Average MPIW: 10.6405
# ==============================
#
#
# ===== TSI EVALUATION METRICS (PCA-based) =====
# Average RMSE: 0.0728
# Average PICP: 0.2326
# Average MPIW: 0.0936
# ==============================
# PCA-based forecasting process completed successfully
